# %% [markdown]
# <a href="https://colab.research.google.com/github/barrosyan/computational_physics_studies/blob/main/Navier_Stokes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reference 1 - First Model: https://github.com/gauravsdeshmukh/FlowPy

# %%
import numpy as np
import os

# %%
class Boundary:
    def __init__(self,boundary_type,boundary_value):
        self.DefineBoundary(boundary_type,boundary_value)

    def DefineBoundary(self,boundary_type,boundary_value):
        self.type=boundary_type
        self.value=boundary_value

# %%
class Space:
    def __init__(self):
        pass

    def CreateMesh(self,rowpts,colpts):
        #Domain gridpoints
        self.rowpts=rowpts
        self.colpts=colpts
        #Velocity matrices
        self.u=np.zeros((self.rowpts+2,self.colpts+2))
        self.v=np.zeros((self.rowpts+2,self.colpts+2))
        self.u_star=np.zeros((self.rowpts+2,self.colpts+2))
        self.v_star=np.zeros((self.rowpts+2,self.colpts+2))
        self.u_next=np.zeros((self.rowpts+2,self.colpts+2))
        self.v_next=np.zeros((self.rowpts+2,self.colpts+2))
        self.u_c=np.zeros((self.rowpts,self.colpts))
        self.v_c=np.zeros((self.rowpts,self.colpts))
        #Pressure matrices
        self.p=np.zeros((self.rowpts+2,self.colpts+2))
        self.p_c=np.zeros((self.rowpts,self.colpts))

        #Set default source term
        self.SetSourceTerm()

    def SetDeltas(self,breadth,length):
        self.dx=length/(self.colpts-1)
        self.dy=breadth/(self.rowpts-1)
    def SetInitialU(self,U):
        self.u=U*self.u

    def SetInitialV(self,V):
        self.v=V*self.v

    def SetInitialP(self,P):
        self.p=P*self.p
    def SetSourceTerm(self,S_x=0,S_y=0):
        self.S_x=S_x
        self.S_y=S_y

# %%
class Fluid:
    def __init__(self,rho,mu):
        self.SetFluidProperties(rho,mu)

    def SetFluidProperties(self,rho,mu):
        self.rho=rho
        self.mu=mu

# %%
#Note: The arguments to the function are all objects of our defined classes
#Set boundary conditions for horizontal velocity
def SetUBoundary(space,left,right,top,bottom):
    if(left.type=="D"):
        space.u[:,0]=left.value
    elif(left.type=="N"):
        space.u[:,0]=-left.value*space.dx+space.u[:,1]

    if(right.type=="D"):
        space.u[:,-1]=right.value
    elif(right.type=="N"):
        space.u[:,-1]=right.value*space.dx+space.u[:,-2]

    if(top.type=="D"):
        space.u[-1,:]=2*top.value-space.u[-2,:]
    elif(top.type=="N"):
        space.u[-1,:]=-top.value*space.dy+space.u[-2,:]

    if(bottom.type=="D"):
        space.u[0,:]=2*bottom.value-space.u[1,:]
    elif(bottom.type=="N"):
        space.u[0,:]=bottom.value*space.dy+space.u[1,:]

#Set boundary conditions for vertical velocity
def SetVBoundary(space,left,right,top,bottom):
    if(left.type=="D"):
        space.v[:,0]=2*left.value-space.v[:,1]
    elif(left.type=="N"):
        space.v[:,0]=-left.value*space.dx+space.v[:,1]

    if(right.type=="D"):
        space.v[:,-1]=2*right.value-space.v[:,-2]
    elif(right.type=="N"):
        space.v[:,-1]=right.value*space.dx+space.v[:,-2]

    if(top.type=="D"):
        space.v[-1,:]=top.value
    elif(top.type=="N"):
        space.v[-1,:]=-top.value*space.dy+space.v[-2,:]

    if(bottom.type=="D"):
        space.v[0,:]=bottom.value
    elif(bottom.type=="N"):
        space.v[0,:]=bottom.value*space.dy+space.v[1,:]
#Set boundary conditions for pressure
def SetPBoundary(space,left,right,top,bottom):
    if(left.type=="D"):
        space.p[:,0]=left.value
    elif(left.type=="N"):
        space.p[:,0]=-left.value*space.dx+space.p[:,1]

    if(right.type=="D"):
        space.p[1,-1]=right.value
    elif(right.type=="N"):
        space.p[:,-1]=right.value*space.dx+space.p[:,-2]

    if(top.type=="D"):
        space.p[-1,:]=top.value
    elif(top.type=="N"):
        space.p[-1,:]=-top.value*space.dy+space.p[-2,:]

    if(bottom.type=="D"):
        space.p[0,:]=bottom.value
    elif(bottom.type=="N"):
        space.p[0,:]=bottom.value*space.dy+space.p[1,:]

# %%
def SetTimeStep(CFL,space,fluid):
    with np.errstate(divide='ignore'):
        dt=CFL/np.sum([np.amax(space.u)/space.dx,\
                           np.amax(space.v)/space.dy])
    #Escape condition if dt is infinity due to zero velocity initially
    if np.isinf(dt):
        dt=CFL*(space.dx+space.dy)
    space.dt=dt

# %%
#The first function is used to get starred velocities from u and v at timestep t
def GetStarredVelocities(space,fluid):
    #Save object attributes as local variable with explicity typing for improved readability
    rows=int(space.rowpts)
    cols=int(space.colpts)
    u=space.u.astype(float,copy=False)
    v=space.v.astype(float,copy=False)
    dx=float(space.dx)
    dy=float(space.dy)
    dt=float(space.dt)
    S_x=float(space.S_x)
    S_y=float(space.S_y)
    rho=float(fluid.rho)
    mu=float(fluid.mu)

    #Copy u and v to new variables u_star and v_star
    u_star=u.copy()
    v_star=v.copy()

    #Calculate derivatives of u and v using the finite difference scheme.
    #Numpy vectorization saves us from using slower for loops to go over each element in the u and v matrices
    u1_y=(u[2:,1:cols+1]-u[0:rows,1:cols+1])/(2*dy)
    u1_x=(u[1:rows+1,2:]-u[1:rows+1,0:cols])/(2*dx)
    u2_y=(u[2:,1:cols+1]-2*u[1:rows+1,1:cols+1]+u[0:rows,1:cols+1])/(dy**2)
    u2_x=(u[1:rows+1,2:]-2*u[1:rows+1,1:cols+1]+u[1:rows+1,0:cols])/(dx**2)
    v_face=(v[1:rows+1,1:cols+1]+v[1:rows+1,0:cols]+v[2:,1:cols+1]+v[2:,0:cols])/4
    u_star[1:rows+1,1:cols+1]=u[1:rows+1,1:cols+1]-dt*(u[1:rows+1,1:cols+1]*u1_x+v_face*u1_y)+(dt*(mu/rho)*(u2_x+u2_y))+(dt*S_x)

    v1_y=(v[2:,1:cols+1]-v[0:rows,1:cols+1])/(2*dy)
    v1_x=(v[1:rows+1,2:]-v[1:rows+1,0:cols])/(2*dx)
    v2_y=(v[2:,1:cols+1]-2*v[1:rows+1,1:cols+1]+v[0:rows,1:cols+1])/(dy**2)
    v2_x=(v[1:rows+1,2:]-2*v[1:rows+1,1:cols+1]+v[1:rows+1,0:cols])/(dx**2)
    u_face=(u[1:rows+1,1:cols+1]+u[1:rows+1,2:]+u[0:rows,1:cols+1]+u[0:rows,2:])/4
    v_star[1:rows+1,1:cols+1]=v[1:rows+1,1:cols+1]-dt*(u_face*v1_x+v[1:rows+1,1:cols+1]*v1_y)+(dt*(mu/rho)*(v2_x+v2_y))+(dt*S_y)

    #Save the calculated starred velocities to the space object
    space.u_star=u_star.copy()
    space.v_star=v_star.copy()


#The second function is used to iteratively solve the pressure Possion equation from the starred velocities
#to calculate pressure at t+delta_t
def SolvePressurePoisson(space,fluid,left,right,top,bottom):
    #Save object attributes as local variable with explicity typing for improved readability
    rows=int(space.rowpts)
    cols=int(space.colpts)
    u_star=space.u_star.astype(float,copy=False)
    v_star=space.v_star.astype(float,copy=False)
    p=space.p.astype(float,copy=False)
    dx=float(space.dx)
    dy=float(space.dy)
    dt=float(space.dt)
    rho=float(fluid.rho)
    factor=1/(2/dx**2+2/dy**2)

    #Define initial error and tolerance for convergence (error > tol necessary initially)
    error=1
    tol=1e-3

    #Evaluate derivative of starred velocities
    ustar1_x=(u_star[1:rows+1,2:]-u_star[1:rows+1,0:cols])/(2*dx)
    vstar1_y=(v_star[2:,1:cols+1]-v_star[0:rows,1:cols+1])/(2*dy)

    #Continue iterative solution until error becomes smaller than tolerance
    i=0
    while(error>tol):
        i+=1

        #Save current pressure as p_old
        p_old=p.astype(float,copy=True)

        #Evaluate second derivative of pressure from p_old
        p2_xy=(p_old[2:,1:cols+1]+p_old[0:rows,1:cols+1])/dy**2+(p_old[1:rows+1,2:]+p_old[1:rows+1,0:cols])/dx**2

        #Calculate new pressure
        p[1:rows+1,1:cols+1]=(p2_xy)*factor-(rho*factor/dt)*(ustar1_x+vstar1_y)

        #Find maximum error between old and new pressure matrices
        error=np.amax(abs(p-p_old))

        #Apply pressure boundary conditions
        SetPBoundary(space,left,right,top,bottom)

        #Escape condition in case solution does not converge after 500 iterations
        if(i>500):
            tol*=10


#The third function is used to calculate the velocities at timestep t+delta_t using the pressure at t+delta_t and starred velocities
def SolveMomentumEquation(space,fluid):
    #Save object attributes as local variable with explicity typing for improved readability
    rows=int(space.rowpts)
    cols=int(space.colpts)
    u_star=space.u_star.astype(float,copy=False)
    v_star=space.v_star.astype(float,copy=False)
    p=space.p.astype(float,copy=False)
    dx=float(space.dx)
    dy=float(space.dy)
    dt=float(space.dt)
    rho=float(fluid.rho)
    u=space.u.astype(float,copy=False)
    v=space.v.astype(float,copy=False)

    #Evaluate first derivative of pressure in x direction
    p1_x=(p[1:rows+1,2:]-p[1:rows+1,0:cols])/(2*dx)
    #Calculate u at next timestep
    u[1:rows+1,1:cols+1]=u_star[1:rows+1,1:cols+1]-(dt/rho)*p1_x

    #Evaluate first derivative of pressure in y direction
    p1_y=(p[2:,1:cols+1]-p[0:rows,1:cols+1])/(2*dy)
    #Calculate v at next timestep
    v[1:rows+1,1:cols+1]=v_star[1:rows+1,1:cols+1]-(dt/rho)*p1_y

# %%
def SetCentrePUV(space):
    space.p_c=space.p[1:-1,1:-1]
    space.u_c=space.u[1:-1,1:-1]
    space.v_c=space.v[1:-1,1:-1]

# %%
def MakeResultDirectory(wipe=False):
    #Get path to the Result directory
    cwdir=os.getcwd()
    dir_path=os.path.join(cwdir,"Result")
    #If directory does not exist, make it
    if not os.path.isdir(dir_path):
        os.makedirs(dir_path,exist_ok=True)
    else:
        #If wipe is True, remove files present in the directory
        if wipe:
            os.chdir(dir_path)
            filelist=os.listdir()
            for file in filelist:
                os.remove(file)

    os.chdir(cwdir)


def WriteToFile(space,iteration,interval):
    if(iteration%interval==0):
        dir_path=os.path.join(os.getcwd(),"Result")
        filename="PUV{0}.txt".format(iteration)
        path=os.path.join(dir_path,filename)
        with open(path,"w") as f:
            for i in range(space.rowpts):
                for j in range(space.colpts):
                    f.write("{}\t{}\t{}\n".format(space.p_c[i,j],space.u_c[i,j],space.v_c[i,j]))

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
#### SPATIAL AND TEMPORAL INPUTS
length=4 #Length of computational domain in the x-direction
breadth=4 #Breadth of computational domain in the y-direction
colpts=257 #Number of grid points in the x-direction #KEEP ODD
rowpts=257 #Number of grid points in the y-direction #KEEP ODD
#Create an object of the class Space called cavity
cavity=Space()

# %%
cavity.CreateMesh(rowpts,colpts)
cavity.SetDeltas(breadth,length)

# %%
#### FLUID PROPERTIES
rho=1 #Density of fluid
mu=0.01 #Viscosity of fluid
#Create an object of the class Fluid called water
water=Fluid(rho,mu)

# %%
#### BOUNDARY SPECIFICATIONS
u_in=1 #Lid velocity
v_wall=0 #Velocity of fluid at the walls
p_out=0 #Gauge pressure at the boundaries
#Create objects of the class Boundary having either Dirichlet ("D") or Neumann ("N") type boundaries
flow=Boundary("D",u_in)
noslip=Boundary("D",v_wall)
zeroflux=Boundary("N",0)
pressureatm=Boundary("D",p_out)

# %%
#### SIMULATION PARAMETERS
time=150 #Simulation time
CFL_number=0.8 #Reduce this if solution diverges
file_flag=1 #Keep 1 to print results to file
interval=100 #Record values in file per interval number of iterations

# %%
#### RUN SIMULATION
# Print general simulation information
print("######## Beginning FlowPy Simulation ########")
print("#############################################")
print("# Simulation time: {0:.2f}".format(time))
print("# Mesh: {0} x {1}".format(colpts,rowpts))
print("# Re/u: {0:.2f}\tRe/v:{1:.2f}".format(rho*length/mu,rho*breadth/mu))
print("# Save outputs to text file: {0}".format(bool(file_flag)))
## Initialization
# Make directory to store results
MakeResultDirectory(wipe=True)
# Initialize counters
t=0
i=0
## Run
while(t<time):
    #Print time left
    sys.stdout.write("\rSimulation time left: {0:.2f}".format(time-t))
    sys.stdout.flush()
    #Set the time-step
    SetTimeStep(CFL_number,cavity,water)
    timestep=cavity.dt

    #Set boundary conditions
    SetUBoundary(cavity,noslip,noslip,flow,noslip)
    SetVBoundary(cavity,noslip,noslip,noslip,noslip)
    SetPBoundary(cavity,zeroflux,zeroflux,pressureatm,zeroflux)

    #Calculate starred velocities
    GetStarredVelocities(cavity,water)

    #Solve the pressure Poisson equation
    SolvePressurePoisson(cavity,water,zeroflux,zeroflux,\
pressureatm,zeroflux)
    #Solve the momentum equation
    SolveMomentumEquation(cavity,water)
    #Save variables and write to file
    SetCentrePUV(cavity)
    if(file_flag==1):
        WriteToFile(cavity,i,interval)
    #Advance time-step and counter
    t+=timestep
    i+=1
# Out:
# ######## Beginning FlowPy Simulation ########
# #############################################
# # Simulation time: 150.00
# # Mesh: 257 x 257
# # Re/u: 400.00	Re/v:400.00
# # Save outputs to text file: True
# Simulation time left: 0.00

# %%
import numpy as np
import sys
import os
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
#### Simulation inputs
rowpts=257
colpts=257
length=4
breadth=4

# %%
#Go to the Result directory
cwdir=os.getcwd()
dir_path=os.path.join(cwdir,"Result")
os.chdir(dir_path)
#Go through files in the directory and store filenames
filenames=[]
iterations=[]
for root,dirs,files in os.walk(dir_path):
    for datafile in files:
        if "PUV" in datafile:
            filenames.append(datafile)
            no_ext_file=datafile.replace(".txt","").strip()
            iter_no=int(no_ext_file.split("V")[-1])
            iterations.append(iter_no)
#Discern the final iteration and interval
initial_iter=np.amin(iterations)
final_iter=np.amax(iterations)
inter=(final_iter - initial_iter)/(len(iterations)-1)
number_of_frames=len(iterations)
sorted_iterations=np.sort(iterations)

# %%
def read_datafile(iteration):
    #Set filename and path according to given iteration
    filename="PUV{0}.txt".format(iteration)
    filepath=os.path.join(dir_path,filename)
    #Load text file as numpy array
    arr=np.loadtxt(filepath,delimiter="\t")
    rows,cols=arr.shape
    #Define empty arrays for pressure and velocities
    p_p=np.zeros((rowpts,colpts))
    u_p=np.zeros((rowpts,colpts))
    v_p=np.zeros((rowpts,colpts))
    #Organize imported array into variables
    p_arr=arr[:,0]
    u_arr=arr[:,1]
    v_arr=arr[:,2]

    #Reshape 1D data into 2D
    p_p=p_arr.reshape((rowpts,colpts))
    u_p=u_arr.reshape((rowpts,colpts))
    v_p=v_arr.reshape((rowpts,colpts))

    return p_p,u_p,v_p

# %%
#Create mesh for X and Y inputs to the figure
x=np.linspace(0,length,colpts)
y=np.linspace(0,breadth,rowpts)
[X,Y]=np.meshgrid(x,y)
#Determine indexing for stream plot (10 points only)
index_cut_x=int(colpts/10)
index_cut_y=int(rowpts/10)
#Create blank figure
fig=plt.figure(figsize=(16,8))
ax=plt.axes(xlim=(0,length),ylim=(0,breadth))
#Create initial contour and stream plot as well as color bar
p_p,u_p,v_p=read_datafile(0)
ax.set_xlim([0,length])
ax.set_ylim([0,breadth])
ax.set_xlabel("$x$",fontsize=12)
ax.set_ylabel("$y$",fontsize=12)
ax.set_title("Frame No: 0")
cont=ax.contourf(X,Y,p_p)
stream=ax.streamplot(X[::index_cut_y,::index_cut_x],Y[::index_cut_y,::index_cut_x],u_p[::index_cut_y,::index_cut_x],v_p[::index_cut_y,::index_cut_x],color="k")
fig.colorbar(cont)
fig.tight_layout()

# %%
def animate(i):
    #Print frames left to be added to the animation
    sys.stdout.write("\rFrames remaining: {0:03d}".format(len(sorted_iterations)-i))
    sys.stdout.flush()
    #Get iterations in a sequential manner through sorted_iterations
    iteration=sorted_iterations[i]
    #Use the read_datafile function to get pressure and velocities
    p_p,u_p,v_p=read_datafile(iteration)
    #Clear previous plot and make contour and stream plots for current iteration
    ax.clear()
    ax.set_xlim([0,length])
    ax.set_ylim([0,breadth])
    ax.set_xlabel("$x$",fontsize=12)
    ax.set_ylabel("$y$",fontsize=12)
    ax.set_title("Frame No: {0}".format(i))
    cont=ax.contourf(X,Y,p_p)
    stream=ax.streamplot(X[::index_cut_y,::index_cut_x],\
                         Y[::index_cut_y,::index_cut_x],\
                         u_p[::index_cut_y,::index_cut_x],\
                         v_p[::index_cut_y,::index_cut_x],\
                         color="k")
    return cont,stream

# %%
print("######## Making FlowPy Animation ########")
print("#########################################")
anim=animation.FuncAnimation(fig,animate,frames=number_of_frames,interval=50,blit=False)
movie_path=os.path.join(dir_path,"FluidFlowAnimation.mp4")
anim.save(r"{0}".format(movie_path))
print("\nAnimation saved as FluidFlowAnimation.mp4 in Result")
# Out:
# ######## Making FlowPy Animation ########
# #########################################
# Frames remaining: 276
# /usr/local/lib/python3.10/dist-packages/matplotlib/animation.py:884: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(
# Frames remaining: 001
# Animation saved as FluidFlowAnimation.mp4 in Result

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten

# %%
# Set the parameters for the problem
rowpts = 257
colpts = 257
length = 4
breadth = 4
rho = 1
mu = 0.01

# %%
# Create the training data
# Generate random initial conditions for u, v, and p
u_initial = np.random.rand(rowpts, colpts)
v_initial = np.random.rand(rowpts, colpts)
p_initial = np.random.rand(rowpts, colpts)
# Normalize the initial conditions to the range [-1, 1]
u_initial = (u_initial - 0.5) * 2
v_initial = (v_initial - 0.5) * 2
p_initial = (p_initial - 0.5) * 2
# Generate random final conditions for u, v, and p
u_final = np.random.rand(rowpts, colpts)
v_final = np.random.rand(rowpts, colpts)
p_final = np.random.rand(rowpts, colpts)
# Combine the initial conditions into a single input array
input_data = np.stack((u_initial, v_initial, p_initial), axis=-1)
input_data = np.expand_dims(input_data, axis=0)
# Create the target data (desired output) as zeros
target_data = np.stack((u_final, v_final, p_final), axis=-1)
target_data = np.stack((u_final, v_final, p_final), axis=-1)
target_data = np.expand_dims(target_data, axis=0)

# %%
# Define the neural network model
model = Sequential()
model.add(Conv2D(32, kernel_size=3, activation='relu', input_shape=(rowpts, colpts, 3)))
model.add(Conv2D(64, kernel_size=3, activation='relu'))
model.add(Flatten())
model.add(Dense(3))  # Output layer with 3 units for u, v, and p

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the model
history = model.fit(input_data, target_data, epochs=1000, batch_size=1)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 1s 1s/step - loss: 93.5090
# Epoch 2/1000
# 1/1 [==============================] - 1s 926ms/step - loss: 2.7329
# Epoch 3/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 11.3739
# Epoch 4/1000
# 1/1 [==============================] - 0s 456ms/step - loss: 39.9363
# Epoch 5/1000
# 1/1 [==============================] - 0s 433ms/step - loss: 63.1143
# Epoch 6/1000
# 1/1 [==============================] - 0s 445ms/step - loss: 76.0389
# Epoch 7/1000
# 1/1 [==============================] - 0s 444ms/step - loss: 80.2770
# Epoch 8/1000
# 1/1 [==============================] - 0s 439ms/step - loss: 78.6874
# Epoch 9/1000
# 1/1 [==============================] - 0s 450ms/step - loss: 73.7447
# Epoch 10/1000
# 1/1 [==============================] - 0s 424ms/step - loss: 67.1845
# Epoch 11/1000
# 1/1 [==============================] - 0s 438ms/step - loss: 60.1278
# Epoch 12/1000
# 1/1 [==============================] - 0s 404ms/step - loss: 53.2144
# Epoch 13/1000
# 1/1 [==============================] - 0s 407ms/step - loss: 46.7996
# Epoch 14/1000
# 1/1 [==============================] - 0s 440ms/step - loss: 41.0351
# Epoch 15/1000
# 1/1 [==============================] - 0s 430ms/step - loss: 35.9493
# Epoch 16/1000
# 1/1 [==============================] - 0s 453ms/step - loss: 31.5181
# Epoch 17/1000
# 1/1 [==============================] - 0s 439ms/step - loss: 27.6944
# Epoch 18/1000
# 1/1 [==============================] - 0s 446ms/step - loss: 24.4077
# Epoch 19/1000
# 1/1 [==============================] - 0s 421ms/step - loss: 21.5845
# Epoch 20/1000
# 1/1 [==============================] - 0s 435ms/step - loss: 19.1650
# Epoch 21/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 17.0874
# Epoch 22/1000
# 1/1 [==============================] - 0s 405ms/step - loss: 15.3034
# Epoch 23/1000
# 1/1 [==============================] - 0s 435ms/step - loss: 13.7682
# Epoch 24/1000
# 1/1 [==============================] - 0s 495ms/step - loss: 12.4426
# Epoch 25/1000
# 1/1 [==============================] - 1s 752ms/step - loss: 11.2942
# Epoch 26/1000
# 1/1 [==============================] - 1s 786ms/step - loss: 10.2961
# Epoch 27/1000
# 1/1 [==============================] - 1s 759ms/step - loss: 9.4255
# Epoch 28/1000
# 1/1 [==============================] - 1s 790ms/step - loss: 8.6637
# Epoch 29/1000
# 1/1 [==============================] - 1s 734ms/step - loss: 7.9953
# Epoch 30/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 7.4070
# Epoch 31/1000
# 1/1 [==============================] - 0s 432ms/step - loss: 6.8871
# Epoch 32/1000
# 1/1 [==============================] - 0s 436ms/step - loss: 6.4259
# Epoch 33/1000
# 1/1 [==============================] - 0s 441ms/step - loss: 6.0157
# Epoch 34/1000
# 1/1 [==============================] - 0s 436ms/step - loss: 5.6495
# Epoch 35/1000
# 1/1 [==============================] - 0s 431ms/step - loss: 5.3215
# Epoch 36/1000
# 1/1 [==============================] - 0s 450ms/step - loss: 5.0270
# Epoch 37/1000
# 1/1 [==============================] - 0s 396ms/step - loss: 4.7618
# Epoch 38/1000
# 1/1 [==============================] - 0s 420ms/step - loss: 4.5220
# Epoch 39/1000
# 1/1 [==============================] - 0s 425ms/step - loss: 4.3044
# Epoch 40/1000
# 1/1 [==============================] - 0s 435ms/step - loss: 4.1064
# Epoch 41/1000
# 1/1 [==============================] - 0s 444ms/step - loss: 3.9257
# Epoch 42/1000
# 1/1 [==============================] - 0s 421ms/step - loss: 3.7602
# Epoch 43/1000
# 1/1 [==============================] - 0s 417ms/step - loss: 3.6083
# Epoch 44/1000
# 1/1 [==============================] - 0s 405ms/step - loss: 3.4684
# Epoch 45/1000
# 1/1 [==============================] - 0s 423ms/step - loss: 3.3392
# Epoch 46/1000
# 1/1 [==============================] - 0s 402ms/step - loss: 3.2196
# Epoch 47/1000
# 1/1 [==============================] - 0s 402ms/step - loss: 3.1086
# Epoch 48/1000
# 1/1 [==============================] - 0s 439ms/step - loss: 3.0053
# Epoch 49/1000
# 1/1 [==============================] - 0s 419ms/step - loss: 2.9090
# Epoch 50/1000
# 1/1 [==============================] - 0s 448ms/step - loss: 2.8188
# Epoch 51/1000
# 1/1 [==============================] - 0s 408ms/step - loss: 2.7343
# Epoch 52/1000
# 1/1 [==============================] - 0s 442ms/step - loss: 2.6549
# Epoch 53/1000
# 1/1 [==============================] - 0s 446ms/step - loss: 2.5800
# Epoch 54/1000
# 1/1 [==============================] - 1s 676ms/step - loss: 2.5094
# Epoch 55/1000
# 1/1 [==============================] - 1s 807ms/step - loss: 2.4425
# Epoch 56/1000
# 1/1 [==============================] - 1s 820ms/step - loss: 2.3791
# Epoch 57/1000
# 1/1 [==============================] - 1s 822ms/step - loss: 2.3189
# Epoch 58/1000
# 1/1 [==============================] - 1s 767ms/step - loss: 2.2615
# Epoch 59/1000
# 1/1 [==============================] - 1s 672ms/step - loss: 2.2068
# Epoch 60/1000
# 1/1 [==============================] - 0s 439ms/step - loss: 2.1545
# Epoch 61/1000
# 1/1 [==============================] - 0s 424ms/step - loss: 2.1045
# Epoch 62/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 2.0565
# Epoch 63/1000
# 1/1 [==============================] - 0s 437ms/step - loss: 2.0105
# Epoch 64/1000
# 1/1 [==============================] - 0s 430ms/step - loss: 1.9662
# Epoch 65/1000
# 1/1 [==============================] - 0s 445ms/step - loss: 1.9235
# Epoch 66/1000
# 1/1 [==============================] - 0s 441ms/step - loss: 1.8824
# Epoch 67/1000
# 1/1 [==============================] - 0s 443ms/step - loss: 1.8426
# Epoch 68/1000
# 1/1 [==============================] - 0s 442ms/step - loss: 1.8043
# Epoch 69/1000
# 1/1 [==============================] - 0s 443ms/step - loss: 1.7671
# Epoch 70/1000
# 1/1 [==============================] - 0s 433ms/step - loss: 1.7311
# Epoch 71/1000
# 1/1 [==============================] - 0s 439ms/step - loss: 1.6962
# Epoch 72/1000
# 1/1 [==============================] - 0s 437ms/step - loss: 1.6623
# Epoch 73/1000
# 1/1 [==============================] - 0s 467ms/step - loss: 1.6294
# Epoch 74/1000
# 1/1 [==============================] - 0s 439ms/step - loss: 1.5974
# Epoch 75/1000
# 1/1 [==============================] - 0s 445ms/step - loss: 1.5663
# Epoch 76/1000
# 1/1 [==============================] - 0s 457ms/step - loss: 1.5359
# Epoch 77/1000
# 1/1 [==============================] - 0s 433ms/step - loss: 1.5064
# Epoch 78/1000
# 1/1 [==============================] - 0s 437ms/step - loss: 1.4776
# Epoch 79/1000
# 1/1 [==============================] - 0s 431ms/step - loss: 1.4495
# Epoch 80/1000
# 1/1 [==============================] - 0s 406ms/step - loss: 1.4221
# Epoch 81/1000
# 1/1 [==============================] - 0s 408ms/step - loss: 1.3953
# Epoch 82/1000
# 1/1 [==============================] - 1s 514ms/step - loss: 1.3692
# Epoch 83/1000
# 1/1 [==============================] - 1s 807ms/step - loss: 1.3436
# Epoch 84/1000
# 1/1 [==============================] - 1s 793ms/step - loss: 1.3186
# Epoch 85/1000
# 1/1 [==============================] - 1s 761ms/step - loss: 1.2942
# Epoch 86/1000
# 1/1 [==============================] - 1s 749ms/step - loss: 1.2703
# Epoch 87/1000
# 1/1 [==============================] - 1s 793ms/step - loss: 1.2469
# Epoch 88/1000
# 1/1 [==============================] - 1s 557ms/step - loss: 1.2240
# Epoch 89/1000
# 1/1 [==============================] - 0s 445ms/step - loss: 1.2016
# Epoch 90/1000
# 1/1 [==============================] - 0s 415ms/step - loss: 1.1796
# Epoch 91/1000
# 1/1 [==============================] - 0s 452ms/step - loss: 1.1581
# Epoch 92/1000
# 1/1 [==============================] - 0s 409ms/step - loss: 1.1370
# Epoch 93/1000
# 1/1 [==============================] - 0s 419ms/step - loss: 1.1164
# Epoch 94/1000
# 1/1 [==============================] - 0s 416ms/step - loss: 1.0961
# Epoch 95/1000
# 1/1 [==============================] - 0s 405ms/step - loss: 1.0763
# Epoch 96/1000
# 1/1 [==============================] - 0s 462ms/step - loss: 1.0568
# Epoch 97/1000
# 1/1 [==============================] - 0s 428ms/step - loss: 1.0377
# Epoch 98/1000
# 1/1 [==============================] - 0s 449ms/step - loss: 1.0190
# Epoch 99/1000
# 1/1 [==============================] - 0s 437ms/step - loss: 1.0007
# Epoch 100/1000
# 1/1 [==============================] - 0s 440ms/step - loss: 0.9827
# Epoch 101/1000
# 1/1 [==============================] - 0s 435ms/step - loss: 0.9650
# Epoch 102/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.9477
# Epoch 103/1000
# 1/1 [==============================] - 0s 424ms/step - loss: 0.9307
# Epoch 104/1000
# 1/1 [==============================] - 0s 402ms/step - loss: 0.9141
# Epoch 105/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.8977
# Epoch 106/1000
# 1/1 [==============================] - 0s 423ms/step - loss: 0.8817
# Epoch 107/1000
# 1/1 [==============================] - 0s 435ms/step - loss: 0.8660
# Epoch 108/1000
# 1/1 [==============================] - 0s 450ms/step - loss: 0.8506
# Epoch 109/1000
# 1/1 [==============================] - 0s 428ms/step - loss: 0.8354
# Epoch 110/1000
# 1/1 [==============================] - 0s 458ms/step - loss: 0.8206
# Epoch 111/1000
# 1/1 [==============================] - 0s 484ms/step - loss: 0.8060
# Epoch 112/1000
# 1/1 [==============================] - 1s 670ms/step - loss: 0.7917
# Epoch 113/1000
# 1/1 [==============================] - 1s 722ms/step - loss: 0.7777
# Epoch 114/1000
# 1/1 [==============================] - 1s 745ms/step - loss: 0.7639
# Epoch 115/1000
# 1/1 [==============================] - 1s 797ms/step - loss: 0.7504
# Epoch 116/1000
# 1/1 [==============================] - 1s 810ms/step - loss: 0.7372
# Epoch 117/1000
# 1/1 [==============================] - 1s 706ms/step - loss: 0.7242
# Epoch 118/1000
# 1/1 [==============================] - 0s 448ms/step - loss: 0.7114
# Epoch 119/1000
# 1/1 [==============================] - 0s 443ms/step - loss: 0.6989
# Epoch 120/1000
# 1/1 [==============================] - 0s 438ms/step - loss: 0.6866
# Epoch 121/1000
# 1/1 [==============================] - 0s 427ms/step - loss: 0.6746
# Epoch 122/1000
# 1/1 [==============================] - 0s 435ms/step - loss: 0.6627
# Epoch 123/1000
# 1/1 [==============================] - 0s 436ms/step - loss: 0.6512
# Epoch 124/1000
# 1/1 [==============================] - 0s 439ms/step - loss: 0.6398
# Epoch 125/1000
# 1/1 [==============================] - 0s 443ms/step - loss: 0.6286
# Epoch 126/1000
# 1/1 [==============================] - 0s 440ms/step - loss: 0.6177
# Epoch 127/1000
# 1/1 [==============================] - 0s 429ms/step - loss: 0.6069
# Epoch 128/1000
# 1/1 [==============================] - 0s 441ms/step - loss: 0.5964
# Epoch 129/1000
# 1/1 [==============================] - 0s 449ms/step - loss: 0.5860
# Epoch 130/1000
# 1/1 [==============================] - 0s 442ms/step - loss: 0.5758
# Epoch 131/1000
# 1/1 [==============================] - 0s 429ms/step - loss: 0.5659
# Epoch 132/1000
# 1/1 [==============================] - 0s 437ms/step - loss: 0.5561
# Epoch 133/1000
# 1/1 [==============================] - 0s 439ms/step - loss: 0.5465
# Epoch 134/1000
# 1/1 [==============================] - 0s 451ms/step - loss: 0.5371
# Epoch 135/1000
# 1/1 [==============================] - 0s 428ms/step - loss: 0.5279
# Epoch 136/1000
# 1/1 [==============================] - 0s 478ms/step - loss: 0.5188
# Epoch 137/1000
# 1/1 [==============================] - 0s 438ms/step - loss: 0.5100
# Epoch 138/1000
# 1/1 [==============================] - 0s 436ms/step - loss: 0.5012
# Epoch 139/1000
# 1/1 [==============================] - 0s 451ms/step - loss: 0.4927
# Epoch 140/1000
# 1/1 [==============================] - 1s 579ms/step - loss: 0.4843
# Epoch 141/1000
# 1/1 [==============================] - 1s 773ms/step - loss: 0.4761
# Epoch 142/1000
# 1/1 [==============================] - 1s 796ms/step - loss: 0.4680
# Epoch 143/1000
# 1/1 [==============================] - 1s 792ms/step - loss: 0.4601
# Epoch 144/1000
# 1/1 [==============================] - 1s 817ms/step - loss: 0.4524
# Epoch 145/1000
# 1/1 [==============================] - 1s 767ms/step - loss: 0.4448
# Epoch 146/1000
# 1/1 [==============================] - 0s 447ms/step - loss: 0.4373
# Epoch 147/1000
# 1/1 [==============================] - 0s 428ms/step - loss: 0.4300
# Epoch 148/1000
# 1/1 [==============================] - 0s 424ms/step - loss: 0.4228
# Epoch 149/1000
# 1/1 [==============================] - 0s 442ms/step - loss: 0.4157
# Epoch 150/1000
# 1/1 [==============================] - 0s 438ms/step - loss: 0.4088
# Epoch 151/1000
# 1/1 [==============================] - 0s 455ms/step - loss: 0.4021
# Epoch 152/1000
# 1/1 [==============================] - 0s 435ms/step - loss: 0.3954
# Epoch 153/1000
# 1/1 [==============================] - 0s 446ms/step - loss: 0.3889
# Epoch 154/1000
# 1/1 [==============================] - 0s 425ms/step - loss: 0.3825
# Epoch 155/1000
# 1/1 [==============================] - 0s 439ms/step - loss: 0.3763
# Epoch 156/1000
# 1/1 [==============================] - 0s 445ms/step - loss: 0.3701
# Epoch 157/1000
# 1/1 [==============================] - 0s 429ms/step - loss: 0.3641
# Epoch 158/1000
# 1/1 [==============================] - 0s 452ms/step - loss: 0.3582
# Epoch 159/1000
# 1/1 [==============================] - 0s 444ms/step - loss: 0.3524
# Epoch 160/1000
# 1/1 [==============================] - 0s 420ms/step - loss: 0.3468
# Epoch 161/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.3412
# Epoch 162/1000
# 1/1 [==============================] - 0s 405ms/step - loss: 0.3357
# Epoch 163/1000
# 1/1 [==============================] - 0s 443ms/step - loss: 0.3304
# Epoch 164/1000
# 1/1 [==============================] - 0s 439ms/step - loss: 0.3252
# Epoch 165/1000
# 1/1 [==============================] - 0s 486ms/step - loss: 0.3200
# Epoch 166/1000
# 1/1 [==============================] - 0s 444ms/step - loss: 0.3150
# Epoch 167/1000
# 1/1 [==============================] - 0s 441ms/step - loss: 0.3101
# Epoch 168/1000
# 1/1 [==============================] - 0s 496ms/step - loss: 0.3052
# Epoch 169/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.3005
# Epoch 170/1000
# 1/1 [==============================] - 1s 935ms/step - loss: 0.2958
# Epoch 171/1000
# 1/1 [==============================] - 1s 753ms/step - loss: 0.2913
# Epoch 172/1000
# 1/1 [==============================] - 1s 810ms/step - loss: 0.2868
# Epoch 173/1000
# 1/1 [==============================] - 1s 710ms/step - loss: 0.2825
# Epoch 174/1000
# 1/1 [==============================] - 0s 445ms/step - loss: 0.2782
# Epoch 175/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.2740
# Epoch 176/1000
# 1/1 [==============================] - 0s 436ms/step - loss: 0.2699
# Epoch 177/1000
# 1/1 [==============================] - 0s 441ms/step - loss: 0.2658
# Epoch 178/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 0.2619
# Epoch 179/1000
# 1/1 [==============================] - 0s 420ms/step - loss: 0.2580
# Epoch 180/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.2542
# Epoch 181/1000
# 1/1 [==============================] - 0s 449ms/step - loss: 0.2505
# Epoch 182/1000
# 1/1 [==============================] - 0s 440ms/step - loss: 0.2469
# Epoch 183/1000
# 1/1 [==============================] - 0s 445ms/step - loss: 0.2433
# Epoch 184/1000
# 1/1 [==============================] - 0s 447ms/step - loss: 0.2398
# Epoch 185/1000
# 1/1 [==============================] - 0s 451ms/step - loss: 0.2364
# Epoch 186/1000
# 1/1 [==============================] - 0s 447ms/step - loss: 0.2330
# Epoch 187/1000
# 1/1 [==============================] - 0s 431ms/step - loss: 0.2297
# Epoch 188/1000
# 1/1 [==============================] - 0s 420ms/step - loss: 0.2265
# Epoch 189/1000
# 1/1 [==============================] - 0s 415ms/step - loss: 0.2234
# Epoch 190/1000
# 1/1 [==============================] - 0s 445ms/step - loss: 0.2203
# Epoch 191/1000
# 1/1 [==============================] - 0s 443ms/step - loss: 0.2172
# Epoch 192/1000
# 1/1 [==============================] - 0s 426ms/step - loss: 0.2143
# Epoch 193/1000
# 1/1 [==============================] - 0s 432ms/step - loss: 0.2114
# Epoch 194/1000
# 1/1 [==============================] - 1s 612ms/step - loss: 0.2085
# Epoch 195/1000
# 1/1 [==============================] - 1s 956ms/step - loss: 0.2058
# Epoch 196/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.2030
# Epoch 197/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.2004
# Epoch 198/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.1978
# Epoch 199/1000
# 1/1 [==============================] - 1s 848ms/step - loss: 0.1952
# Epoch 200/1000
# 1/1 [==============================] - 1s 699ms/step - loss: 0.1927
# Epoch 201/1000
# 1/1 [==============================] - 1s 803ms/step - loss: 0.1902
# Epoch 202/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.1878
# Epoch 203/1000
# 1/1 [==============================] - 1s 834ms/step - loss: 0.1855
# Epoch 204/1000
# 1/1 [==============================] - 1s 903ms/step - loss: 0.1832
# Epoch 205/1000
# 1/1 [==============================] - 1s 720ms/step - loss: 0.1809
# Epoch 206/1000
# 1/1 [==============================] - 1s 684ms/step - loss: 0.1787
# Epoch 207/1000
# 1/1 [==============================] - 1s 715ms/step - loss: 0.1766
# Epoch 208/1000
# 1/1 [==============================] - 1s 904ms/step - loss: 0.1744
# Epoch 209/1000
# 1/1 [==============================] - 1s 598ms/step - loss: 0.1724
# Epoch 210/1000
# 1/1 [==============================] - 1s 714ms/step - loss: 0.1703
# Epoch 211/1000
# 1/1 [==============================] - 1s 717ms/step - loss: 0.1684
# Epoch 212/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.1664
# Epoch 213/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.1645
# Epoch 214/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.1627
# Epoch 215/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.1608
# Epoch 216/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.1591
# Epoch 217/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.1573
# Epoch 218/1000
# 1/1 [==============================] - 1s 915ms/step - loss: 0.1556
# Epoch 219/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.1539
# Epoch 220/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.1523
# Epoch 221/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.1507
# Epoch 222/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.1491
# Epoch 223/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.1476
# Epoch 224/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.1461
# Epoch 225/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.1446
# Epoch 226/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.1432
# Epoch 227/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.1418
# Epoch 228/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.1404
# Epoch 229/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.1391
# Epoch 230/1000
# 1/1 [==============================] - 1s 715ms/step - loss: 0.1378
# Epoch 231/1000
# 1/1 [==============================] - 1s 772ms/step - loss: 0.1365
# Epoch 232/1000
# 1/1 [==============================] - 1s 684ms/step - loss: 0.1353
# Epoch 233/1000
# 1/1 [==============================] - 1s 837ms/step - loss: 0.1340
# Epoch 234/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.1328
# Epoch 235/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.1317
# Epoch 236/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.1305
# Epoch 237/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.1294
# Epoch 238/1000
# 1/1 [==============================] - 1s 949ms/step - loss: 0.1283
# Epoch 239/1000
# 1/1 [==============================] - 1s 843ms/step - loss: 0.1272
# Epoch 240/1000
# 1/1 [==============================] - 1s 836ms/step - loss: 0.1262
# Epoch 241/1000
# 1/1 [==============================] - 1s 861ms/step - loss: 0.1251
# Epoch 242/1000
# 1/1 [==============================] - 1s 752ms/step - loss: 0.1241
# Epoch 243/1000
# 1/1 [==============================] - 1s 799ms/step - loss: 0.1232
# Epoch 244/1000
# 1/1 [==============================] - 1s 827ms/step - loss: 0.1222
# Epoch 245/1000
# 1/1 [==============================] - 1s 755ms/step - loss: 0.1213
# Epoch 246/1000
# 1/1 [==============================] - 1s 587ms/step - loss: 0.1203
# Epoch 247/1000
# 1/1 [==============================] - 0s 430ms/step - loss: 0.1194
# Epoch 248/1000
# 1/1 [==============================] - 0s 415ms/step - loss: 0.1186
# Epoch 249/1000
# 1/1 [==============================] - 0s 405ms/step - loss: 0.1177
# Epoch 250/1000
# 1/1 [==============================] - 0s 422ms/step - loss: 0.1169
# Epoch 251/1000
# 1/1 [==============================] - 0s 423ms/step - loss: 0.1161
# Epoch 252/1000
# 1/1 [==============================] - 0s 425ms/step - loss: 0.1153
# Epoch 253/1000
# 1/1 [==============================] - 0s 408ms/step - loss: 0.1145
# Epoch 254/1000
# 1/1 [==============================] - 0s 428ms/step - loss: 0.1137
# Epoch 255/1000
# 1/1 [==============================] - 1s 698ms/step - loss: 0.1130
# Epoch 256/1000
# 1/1 [==============================] - 1s 773ms/step - loss: 0.1122
# Epoch 257/1000
# 1/1 [==============================] - 1s 735ms/step - loss: 0.1115
# Epoch 258/1000
# 1/1 [==============================] - 1s 794ms/step - loss: 0.1108
# Epoch 259/1000
# 1/1 [==============================] - 1s 776ms/step - loss: 0.1102
# Epoch 260/1000
# 1/1 [==============================] - 1s 718ms/step - loss: 0.1095
# Epoch 261/1000
# 1/1 [==============================] - 0s 453ms/step - loss: 0.1088
# Epoch 262/1000
# 1/1 [==============================] - 0s 432ms/step - loss: 0.1082
# Epoch 263/1000
# 1/1 [==============================] - 0s 433ms/step - loss: 0.1076
# Epoch 264/1000
# 1/1 [==============================] - 0s 405ms/step - loss: 0.1070
# Epoch 265/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.1064
# Epoch 266/1000
# 1/1 [==============================] - 0s 403ms/step - loss: 0.1058
# Epoch 267/1000
# 1/1 [==============================] - 0s 415ms/step - loss: 0.1053
# Epoch 268/1000
# 1/1 [==============================] - 0s 428ms/step - loss: 0.1047
# Epoch 269/1000
# 1/1 [==============================] - 0s 434ms/step - loss: 0.1042
# Epoch 270/1000
# 1/1 [==============================] - 0s 432ms/step - loss: 0.1036
# Epoch 271/1000
# 1/1 [==============================] - 0s 428ms/step - loss: 0.1031
# Epoch 272/1000
# 1/1 [==============================] - 0s 455ms/step - loss: 0.1026
# Epoch 273/1000
# 1/1 [==============================] - 0s 421ms/step - loss: 0.1021
# Epoch 274/1000
# 1/1 [==============================] - 0s 430ms/step - loss: 0.1017
# Epoch 275/1000
# 1/1 [==============================] - 0s 443ms/step - loss: 0.1012
# Epoch 276/1000
# 1/1 [==============================] - 0s 429ms/step - loss: 0.1008
# Epoch 277/1000
# 1/1 [==============================] - 0s 438ms/step - loss: 0.1003
# Epoch 278/1000
# 1/1 [==============================] - 0s 404ms/step - loss: 0.0999
# Epoch 279/1000
# 1/1 [==============================] - 0s 421ms/step - loss: 0.0995
# Epoch 280/1000
# 1/1 [==============================] - 0s 408ms/step - loss: 0.0990
# Epoch 281/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0986
# Epoch 282/1000
# 1/1 [==============================] - 0s 426ms/step - loss: 0.0982
# Epoch 283/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 0.0979
# Epoch 284/1000
# 1/1 [==============================] - 1s 542ms/step - loss: 0.0975
# Epoch 285/1000
# 1/1 [==============================] - 1s 694ms/step - loss: 0.0971
# Epoch 286/1000
# 1/1 [==============================] - 1s 767ms/step - loss: 0.0968
# Epoch 287/1000
# 1/1 [==============================] - 1s 748ms/step - loss: 0.0964
# Epoch 288/1000
# 1/1 [==============================] - 1s 765ms/step - loss: 0.0961
# Epoch 289/1000
# 1/1 [==============================] - 1s 751ms/step - loss: 0.0957
# Epoch 290/1000
# 1/1 [==============================] - 1s 668ms/step - loss: 0.0954
# Epoch 291/1000
# 1/1 [==============================] - 0s 433ms/step - loss: 0.0951
# Epoch 292/1000
# 1/1 [==============================] - 0s 417ms/step - loss: 0.0948
# Epoch 293/1000
# 1/1 [==============================] - 0s 405ms/step - loss: 0.0945
# Epoch 294/1000
# 1/1 [==============================] - 0s 440ms/step - loss: 0.0942
# Epoch 295/1000
# 1/1 [==============================] - 0s 417ms/step - loss: 0.0939
# Epoch 296/1000
# 1/1 [==============================] - 0s 444ms/step - loss: 0.0936
# Epoch 297/1000
# 1/1 [==============================] - 0s 430ms/step - loss: 0.0934
# Epoch 298/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0931
# Epoch 299/1000
# 1/1 [==============================] - 0s 419ms/step - loss: 0.0928
# Epoch 300/1000
# 1/1 [==============================] - 0s 404ms/step - loss: 0.0926
# Epoch 301/1000
# 1/1 [==============================] - 0s 458ms/step - loss: 0.0923
# Epoch 302/1000
# 1/1 [==============================] - 0s 430ms/step - loss: 0.0921
# Epoch 303/1000
# 1/1 [==============================] - 0s 441ms/step - loss: 0.0919
# Epoch 304/1000
# 1/1 [==============================] - 0s 444ms/step - loss: 0.0916
# Epoch 305/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0914
# Epoch 306/1000
# 1/1 [==============================] - 0s 445ms/step - loss: 0.0912
# Epoch 307/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0910
# Epoch 308/1000
# 1/1 [==============================] - 0s 438ms/step - loss: 0.0908
# Epoch 309/1000
# 1/1 [==============================] - 0s 430ms/step - loss: 0.0906
# Epoch 310/1000
# 1/1 [==============================] - 0s 446ms/step - loss: 0.0904
# Epoch 311/1000
# 1/1 [==============================] - 1s 698ms/step - loss: 0.0902
# Epoch 312/1000
# 1/1 [==============================] - 1s 697ms/step - loss: 0.0900
# Epoch 313/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.0898
# Epoch 314/1000
# 1/1 [==============================] - 1s 708ms/step - loss: 0.0897
# Epoch 315/1000
# 1/1 [==============================] - 1s 775ms/step - loss: 0.0895
# Epoch 316/1000
# 1/1 [==============================] - 1s 815ms/step - loss: 0.0893
# Epoch 317/1000
# 1/1 [==============================] - 1s 700ms/step - loss: 0.0891
# Epoch 318/1000
# 1/1 [==============================] - 1s 538ms/step - loss: 0.0890
# Epoch 319/1000
# 1/1 [==============================] - 0s 441ms/step - loss: 0.0888
# Epoch 320/1000
# 1/1 [==============================] - 0s 435ms/step - loss: 0.0887
# Epoch 321/1000
# 1/1 [==============================] - 0s 422ms/step - loss: 0.0885
# Epoch 322/1000
# 1/1 [==============================] - 0s 425ms/step - loss: 0.0884
# Epoch 323/1000
# 1/1 [==============================] - 0s 429ms/step - loss: 0.0882
# Epoch 324/1000
# 1/1 [==============================] - 0s 434ms/step - loss: 0.0881
# Epoch 325/1000
# 1/1 [==============================] - 0s 430ms/step - loss: 0.0880
# Epoch 326/1000
# 1/1 [==============================] - 0s 447ms/step - loss: 0.0879
# Epoch 327/1000
# 1/1 [==============================] - 0s 438ms/step - loss: 0.0877
# Epoch 328/1000
# 1/1 [==============================] - 0s 448ms/step - loss: 0.0876
# Epoch 329/1000
# 1/1 [==============================] - 0s 435ms/step - loss: 0.0875
# Epoch 330/1000
# 1/1 [==============================] - 0s 450ms/step - loss: 0.0874
# Epoch 331/1000
# 1/1 [==============================] - 0s 441ms/step - loss: 0.0873
# Epoch 332/1000
# 1/1 [==============================] - 0s 427ms/step - loss: 0.0871
# Epoch 333/1000
# 1/1 [==============================] - 0s 444ms/step - loss: 0.0870
# Epoch 334/1000
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0869
# Epoch 335/1000
# 1/1 [==============================] - 0s 446ms/step - loss: 0.0868
# Epoch 336/1000
# 1/1 [==============================] - 0s 436ms/step - loss: 0.0867
# Epoch 337/1000
# 1/1 [==============================] - 0s 424ms/step - loss: 0.0866
# Epoch 338/1000
# 1/1 [==============================] - 0s 409ms/step - loss: 0.0865
# Epoch 339/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0864
# Epoch 340/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0864
# Epoch 341/1000
# 1/1 [==============================] - 1s 578ms/step - loss: 0.0863
# Epoch 342/1000
# 1/1 [==============================] - 1s 762ms/step - loss: 0.0862
# Epoch 343/1000
# 1/1 [==============================] - 1s 813ms/step - loss: 0.0861
# Epoch 344/1000
# 1/1 [==============================] - 1s 794ms/step - loss: 0.0860
# Epoch 345/1000
# 1/1 [==============================] - 1s 762ms/step - loss: 0.0859
# Epoch 346/1000
# 1/1 [==============================] - 1s 684ms/step - loss: 0.0859
# Epoch 347/1000
# 1/1 [==============================] - 1s 585ms/step - loss: 0.0858
# Epoch 348/1000
# 1/1 [==============================] - 0s 416ms/step - loss: 0.0857
# Epoch 349/1000
# 1/1 [==============================] - 0s 404ms/step - loss: 0.0857
# Epoch 350/1000
# 1/1 [==============================] - 0s 443ms/step - loss: 0.0856
# Epoch 351/1000
# 1/1 [==============================] - 0s 438ms/step - loss: 0.0855
# Epoch 352/1000
# 1/1 [==============================] - 0s 442ms/step - loss: 0.0855
# Epoch 353/1000
# 1/1 [==============================] - 0s 428ms/step - loss: 0.0854
# Epoch 354/1000
# 1/1 [==============================] - 0s 439ms/step - loss: 0.0853
# Epoch 355/1000
# 1/1 [==============================] - 0s 451ms/step - loss: 0.0853
# Epoch 356/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0852
# Epoch 357/1000
# 1/1 [==============================] - 0s 438ms/step - loss: 0.0852
# Epoch 358/1000
# 1/1 [==============================] - 0s 403ms/step - loss: 0.0851
# Epoch 359/1000
# 1/1 [==============================] - 1s 603ms/step - loss: 0.0851
# Epoch 360/1000
# 1/1 [==============================] - 1s 844ms/step - loss: 0.0850
# Epoch 361/1000
# 1/1 [==============================] - 0s 418ms/step - loss: 0.0850
# Epoch 362/1000
# 1/1 [==============================] - 0s 409ms/step - loss: 0.0849
# Epoch 363/1000
# 1/1 [==============================] - 0s 438ms/step - loss: 0.0849
# Epoch 364/1000
# 1/1 [==============================] - 0s 419ms/step - loss: 0.0848
# Epoch 365/1000
# 1/1 [==============================] - 0s 464ms/step - loss: 0.0848
# Epoch 366/1000
# 1/1 [==============================] - 0s 439ms/step - loss: 0.0847
# Epoch 367/1000
# 1/1 [==============================] - 0s 451ms/step - loss: 0.0847
# Epoch 368/1000
# 1/1 [==============================] - 0s 454ms/step - loss: 0.0846
# Epoch 369/1000
# 1/1 [==============================] - 1s 575ms/step - loss: 0.0846
# Epoch 370/1000
# 1/1 [==============================] - 1s 740ms/step - loss: 0.0846
# Epoch 371/1000
# 1/1 [==============================] - 1s 742ms/step - loss: 0.0845
# Epoch 372/1000
# 1/1 [==============================] - 1s 812ms/step - loss: 0.0845
# Epoch 373/1000
# 1/1 [==============================] - 1s 748ms/step - loss: 0.0844
# Epoch 374/1000
# 1/1 [==============================] - 1s 820ms/step - loss: 0.0844
# Epoch 375/1000
# 1/1 [==============================] - 0s 476ms/step - loss: 0.0844
# Epoch 376/1000
# 1/1 [==============================] - 0s 422ms/step - loss: 0.0843
# Epoch 377/1000
# 1/1 [==============================] - 0s 419ms/step - loss: 0.0843
# Epoch 378/1000
# 1/1 [==============================] - 0s 445ms/step - loss: 0.0843
# Epoch 379/1000
# 1/1 [==============================] - 0s 449ms/step - loss: 0.0843
# Epoch 380/1000
# 1/1 [==============================] - 0s 440ms/step - loss: 0.0842
# Epoch 381/1000
# 1/1 [==============================] - 0s 442ms/step - loss: 0.0842
# Epoch 382/1000
# 1/1 [==============================] - 0s 444ms/step - loss: 0.0842
# Epoch 383/1000
# 1/1 [==============================] - 0s 424ms/step - loss: 0.0841
# Epoch 384/1000
# 1/1 [==============================] - 0s 437ms/step - loss: 0.0841
# Epoch 385/1000
# 1/1 [==============================] - 0s 471ms/step - loss: 0.0841
# Epoch 386/1000
# 1/1 [==============================] - 0s 447ms/step - loss: 0.0841
# Epoch 387/1000
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0840
# Epoch 388/1000
# 1/1 [==============================] - 0s 438ms/step - loss: 0.0840
# Epoch 389/1000
# 1/1 [==============================] - 0s 429ms/step - loss: 0.0840
# Epoch 390/1000
# 1/1 [==============================] - 0s 418ms/step - loss: 0.0840
# Epoch 391/1000
# 1/1 [==============================] - 0s 451ms/step - loss: 0.0840
# Epoch 392/1000
# 1/1 [==============================] - 0s 440ms/step - loss: 0.0839
# Epoch 393/1000
# 1/1 [==============================] - 0s 404ms/step - loss: 0.0839
# Epoch 394/1000
# 1/1 [==============================] - 0s 428ms/step - loss: 0.0839
# Epoch 395/1000
# 1/1 [==============================] - 0s 441ms/step - loss: 0.0839
# Epoch 396/1000
# 1/1 [==============================] - 0s 453ms/step - loss: 0.0839
# Epoch 397/1000
# 1/1 [==============================] - 0s 450ms/step - loss: 0.0838
# Epoch 398/1000
# 1/1 [==============================] - 1s 688ms/step - loss: 0.0838
# Epoch 399/1000
# 1/1 [==============================] - 1s 734ms/step - loss: 0.0838
# Epoch 400/1000
# 1/1 [==============================] - 1s 731ms/step - loss: 0.0838
# Epoch 401/1000
# 1/1 [==============================] - 1s 733ms/step - loss: 0.0838
# Epoch 402/1000
# 1/1 [==============================] - 1s 824ms/step - loss: 0.0838
# Epoch 403/1000
# 1/1 [==============================] - 1s 842ms/step - loss: 0.0837
# Epoch 404/1000
# 1/1 [==============================] - 1s 916ms/step - loss: 0.0837
# Epoch 405/1000
# 1/1 [==============================] - 1s 518ms/step - loss: 0.0837
# Epoch 406/1000
# 1/1 [==============================] - 1s 754ms/step - loss: 0.0837
# Epoch 407/1000
# 1/1 [==============================] - 1s 578ms/step - loss: 0.0837
# Epoch 408/1000
# 1/1 [==============================] - 0s 455ms/step - loss: 0.0837
# Epoch 409/1000
# 1/1 [==============================] - 0s 456ms/step - loss: 0.0837
# Epoch 410/1000
# 1/1 [==============================] - 0s 455ms/step - loss: 0.0837
# Epoch 411/1000
# 1/1 [==============================] - 0s 433ms/step - loss: 0.0836
# Epoch 412/1000
# 1/1 [==============================] - 0s 435ms/step - loss: 0.0836
# Epoch 413/1000
# 1/1 [==============================] - 0s 452ms/step - loss: 0.0836
# Epoch 414/1000
# 1/1 [==============================] - 0s 441ms/step - loss: 0.0836
# Epoch 415/1000
# 1/1 [==============================] - 0s 474ms/step - loss: 0.0836
# Epoch 416/1000
# 1/1 [==============================] - 0s 460ms/step - loss: 0.0836
# Epoch 417/1000
# 1/1 [==============================] - 1s 543ms/step - loss: 0.0836
# Epoch 418/1000
# 1/1 [==============================] - 1s 750ms/step - loss: 0.0836
# Epoch 419/1000
# 1/1 [==============================] - 1s 884ms/step - loss: 0.0836
# Epoch 420/1000
# 1/1 [==============================] - 1s 697ms/step - loss: 0.0836
# Epoch 421/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.0835
# Epoch 422/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.0835
# Epoch 423/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.0835
# Epoch 424/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.0835
# Epoch 425/1000
# 1/1 [==============================] - 1s 846ms/step - loss: 0.0835
# Epoch 426/1000
# 1/1 [==============================] - 1s 780ms/step - loss: 0.0835
# Epoch 427/1000
# 1/1 [==============================] - 1s 774ms/step - loss: 0.0835
# Epoch 428/1000
# 1/1 [==============================] - 1s 666ms/step - loss: 0.0835
# Epoch 429/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.0835
# Epoch 430/1000
# 1/1 [==============================] - 0s 408ms/step - loss: 0.0835
# Epoch 431/1000
# 1/1 [==============================] - 0s 437ms/step - loss: 0.0835
# Epoch 432/1000
# 1/1 [==============================] - 0s 417ms/step - loss: 0.0835
# Epoch 433/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0835
# Epoch 434/1000
# 1/1 [==============================] - 0s 431ms/step - loss: 0.0835
# Epoch 435/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0835
# Epoch 436/1000
# 1/1 [==============================] - 0s 429ms/step - loss: 0.0834
# Epoch 437/1000
# 1/1 [==============================] - 0s 414ms/step - loss: 0.0834
# Epoch 438/1000
# 1/1 [==============================] - 0s 417ms/step - loss: 0.0834
# Epoch 439/1000
# 1/1 [==============================] - 0s 454ms/step - loss: 0.0834
# Epoch 440/1000
# 1/1 [==============================] - 0s 438ms/step - loss: 0.0834
# Epoch 441/1000
# 1/1 [==============================] - 0s 430ms/step - loss: 0.0834
# Epoch 442/1000
# 1/1 [==============================] - 0s 407ms/step - loss: 0.0834
# Epoch 443/1000
# 1/1 [==============================] - 0s 452ms/step - loss: 0.0834
# Epoch 444/1000
# 1/1 [==============================] - 1s 732ms/step - loss: 0.0834
# Epoch 445/1000
# 1/1 [==============================] - 1s 751ms/step - loss: 0.0834
# Epoch 446/1000
# 1/1 [==============================] - 1s 789ms/step - loss: 0.0834
# Epoch 447/1000
# 1/1 [==============================] - 1s 716ms/step - loss: 0.0834
# Epoch 448/1000
# 1/1 [==============================] - 1s 724ms/step - loss: 0.0834
# Epoch 449/1000
# 1/1 [==============================] - 1s 699ms/step - loss: 0.0834
# Epoch 450/1000
# 1/1 [==============================] - 1s 523ms/step - loss: 0.0834
# Epoch 451/1000
# 1/1 [==============================] - 0s 422ms/step - loss: 0.0834
# Epoch 452/1000
# 1/1 [==============================] - 0s 420ms/step - loss: 0.0834
# Epoch 453/1000
# 1/1 [==============================] - 0s 455ms/step - loss: 0.0834
# Epoch 454/1000
# 1/1 [==============================] - 0s 429ms/step - loss: 0.0834
# Epoch 455/1000
# 1/1 [==============================] - 0s 442ms/step - loss: 0.0834
# Epoch 456/1000
# 1/1 [==============================] - 0s 460ms/step - loss: 0.0834
# Epoch 457/1000
# 1/1 [==============================] - 0s 433ms/step - loss: 0.0834
# Epoch 458/1000
# 1/1 [==============================] - 0s 416ms/step - loss: 0.0834
# Epoch 459/1000
# 1/1 [==============================] - 0s 422ms/step - loss: 0.0834
# Epoch 460/1000
# 1/1 [==============================] - 0s 464ms/step - loss: 0.0834
# Epoch 461/1000
# 1/1 [==============================] - 0s 450ms/step - loss: 0.0834
# Epoch 462/1000
# 1/1 [==============================] - 0s 456ms/step - loss: 0.0834
# Epoch 463/1000
# 1/1 [==============================] - 0s 426ms/step - loss: 0.0834
# Epoch 464/1000
# 1/1 [==============================] - 0s 428ms/step - loss: 0.0834
# Epoch 465/1000
# 1/1 [==============================] - 0s 431ms/step - loss: 0.0834
# Epoch 466/1000
# 1/1 [==============================] - 0s 423ms/step - loss: 0.0833
# Epoch 467/1000
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0833
# Epoch 468/1000
# 1/1 [==============================] - 0s 433ms/step - loss: 0.0833
# Epoch 469/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0833
# Epoch 470/1000
# 1/1 [==============================] - 0s 431ms/step - loss: 0.0833
# Epoch 471/1000
# 1/1 [==============================] - 0s 416ms/step - loss: 0.0833
# Epoch 472/1000
# 1/1 [==============================] - 0s 462ms/step - loss: 0.0833
# Epoch 473/1000
# 1/1 [==============================] - 1s 595ms/step - loss: 0.0833
# Epoch 474/1000
# 1/1 [==============================] - 1s 775ms/step - loss: 0.0833
# Epoch 475/1000
# 1/1 [==============================] - 1s 718ms/step - loss: 0.0833
# Epoch 476/1000
# 1/1 [==============================] - 1s 787ms/step - loss: 0.0833
# Epoch 477/1000
# 1/1 [==============================] - 1s 788ms/step - loss: 0.0833
# Epoch 478/1000
# 1/1 [==============================] - 1s 756ms/step - loss: 0.0833
# Epoch 479/1000
# 1/1 [==============================] - 1s 548ms/step - loss: 0.0833
# Epoch 480/1000
# 1/1 [==============================] - 0s 460ms/step - loss: 0.0833
# Epoch 481/1000
# 1/1 [==============================] - 0s 443ms/step - loss: 0.0833
# Epoch 482/1000
# 1/1 [==============================] - 0s 462ms/step - loss: 0.0833
# Epoch 483/1000
# 1/1 [==============================] - 0s 448ms/step - loss: 0.0833
# Epoch 484/1000
# 1/1 [==============================] - 0s 460ms/step - loss: 0.0833
# Epoch 485/1000
# 1/1 [==============================] - 0s 447ms/step - loss: 0.0833
# Epoch 486/1000
# 1/1 [==============================] - 0s 448ms/step - loss: 0.0833
# Epoch 487/1000
# 1/1 [==============================] - 0s 419ms/step - loss: 0.0833
# Epoch 488/1000
# 1/1 [==============================] - 0s 419ms/step - loss: 0.0833
# Epoch 489/1000
# 1/1 [==============================] - 0s 455ms/step - loss: 0.0833
# Epoch 490/1000
# 1/1 [==============================] - 0s 436ms/step - loss: 0.0833
# Epoch 491/1000
# 1/1 [==============================] - 0s 422ms/step - loss: 0.0833
# Epoch 492/1000
# 1/1 [==============================] - 0s 431ms/step - loss: 0.0833
# Epoch 493/1000
# 1/1 [==============================] - 0s 452ms/step - loss: 0.0833
# Epoch 494/1000
# 1/1 [==============================] - 0s 423ms/step - loss: 0.0833
# Epoch 495/1000
# 1/1 [==============================] - 0s 444ms/step - loss: 0.0833
# Epoch 496/1000
# 1/1 [==============================] - 0s 460ms/step - loss: 0.0833
# Epoch 497/1000
# 1/1 [==============================] - 0s 415ms/step - loss: 0.0833
# Epoch 498/1000
# 1/1 [==============================] - 0s 462ms/step - loss: 0.0833
# Epoch 499/1000
# 1/1 [==============================] - 0s 416ms/step - loss: 0.0833
# Epoch 500/1000
# 1/1 [==============================] - 0s 445ms/step - loss: 0.0833
# Epoch 501/1000
# 1/1 [==============================] - 0s 496ms/step - loss: 0.0833
# Epoch 502/1000
# 1/1 [==============================] - 1s 731ms/step - loss: 0.0833
# Epoch 503/1000
# 1/1 [==============================] - 1s 766ms/step - loss: 0.0833
# Epoch 504/1000
# 1/1 [==============================] - 1s 695ms/step - loss: 0.0833
# Epoch 505/1000
# 1/1 [==============================] - 1s 809ms/step - loss: 0.0833
# Epoch 506/1000
# 1/1 [==============================] - 1s 823ms/step - loss: 0.0833
# Epoch 507/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0833
# Epoch 508/1000
# 1/1 [==============================] - 0s 434ms/step - loss: 0.0833
# Epoch 509/1000
# 1/1 [==============================] - 0s 430ms/step - loss: 0.0833
# Epoch 510/1000
# 1/1 [==============================] - 0s 428ms/step - loss: 0.0833
# Epoch 511/1000
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0833
# Epoch 512/1000
# 1/1 [==============================] - 0s 419ms/step - loss: 0.0833
# Epoch 513/1000
# 1/1 [==============================] - 0s 430ms/step - loss: 0.0833
# Epoch 514/1000
# 1/1 [==============================] - 0s 451ms/step - loss: 0.0833
# Epoch 515/1000
# 1/1 [==============================] - 0s 459ms/step - loss: 0.0833
# Epoch 516/1000
# 1/1 [==============================] - 0s 421ms/step - loss: 0.0833
# Epoch 517/1000
# 1/1 [==============================] - 0s 458ms/step - loss: 0.0833
# Epoch 518/1000
# 1/1 [==============================] - 0s 405ms/step - loss: 0.0833
# Epoch 519/1000
# 1/1 [==============================] - 0s 448ms/step - loss: 0.0833
# Epoch 520/1000
# 1/1 [==============================] - 0s 431ms/step - loss: 0.0833
# Epoch 521/1000
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0833
# Epoch 522/1000
# 1/1 [==============================] - 0s 438ms/step - loss: 0.0833
# Epoch 523/1000
# 1/1 [==============================] - 0s 421ms/step - loss: 0.0833
# Epoch 524/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 0.0833
# Epoch 525/1000
# 1/1 [==============================] - 0s 438ms/step - loss: 0.0833
# Epoch 526/1000
# 1/1 [==============================] - 0s 421ms/step - loss: 0.0833
# Epoch 527/1000
# 1/1 [==============================] - 0s 448ms/step - loss: 0.0833
# Epoch 528/1000
# 1/1 [==============================] - 0s 443ms/step - loss: 0.0833
# Epoch 529/1000
# 1/1 [==============================] - 0s 421ms/step - loss: 0.0833
# Epoch 530/1000
# 1/1 [==============================] - 0s 456ms/step - loss: 0.0833
# Epoch 531/1000
# 1/1 [==============================] - 1s 763ms/step - loss: 0.0833
# Epoch 532/1000
# 1/1 [==============================] - 1s 805ms/step - loss: 0.0833
# Epoch 533/1000
# 1/1 [==============================] - 1s 771ms/step - loss: 0.0833
# Epoch 534/1000
# 1/1 [==============================] - 1s 810ms/step - loss: 0.0833
# Epoch 535/1000
# 1/1 [==============================] - 1s 828ms/step - loss: 0.0833
# Epoch 536/1000
# 1/1 [==============================] - 1s 630ms/step - loss: 0.0833
# Epoch 537/1000
# 1/1 [==============================] - 0s 421ms/step - loss: 0.0833
# Epoch 538/1000
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0833
# Epoch 539/1000
# 1/1 [==============================] - 0s 456ms/step - loss: 0.0833
# Epoch 540/1000
# 1/1 [==============================] - 0s 443ms/step - loss: 0.0833
# Epoch 541/1000
# 1/1 [==============================] - 0s 478ms/step - loss: 0.0833
# Epoch 542/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0833
# Epoch 543/1000
# 1/1 [==============================] - 1s 765ms/step - loss: 0.0833
# Epoch 544/1000
# 1/1 [==============================] - 1s 763ms/step - loss: 0.0833
# Epoch 545/1000
# 1/1 [==============================] - 1s 677ms/step - loss: 0.0833
# Epoch 546/1000
# 1/1 [==============================] - 1s 807ms/step - loss: 0.0833
# Epoch 547/1000
# 1/1 [==============================] - 1s 784ms/step - loss: 0.0833
# Epoch 548/1000
# 1/1 [==============================] - 1s 514ms/step - loss: 0.0833
# Epoch 549/1000
# 1/1 [==============================] - 0s 437ms/step - loss: 0.0833
# Epoch 550/1000
# 1/1 [==============================] - 0s 430ms/step - loss: 0.0833
# Epoch 551/1000
# 1/1 [==============================] - 0s 439ms/step - loss: 0.0833
# Epoch 552/1000
# 1/1 [==============================] - 0s 444ms/step - loss: 0.0833
# Epoch 553/1000
# 1/1 [==============================] - 0s 448ms/step - loss: 0.0833
# Epoch 554/1000
# 1/1 [==============================] - 0s 451ms/step - loss: 0.0833
# Epoch 555/1000
# 1/1 [==============================] - 1s 662ms/step - loss: 0.0833
# Epoch 556/1000
# 1/1 [==============================] - 1s 749ms/step - loss: 0.0833
# Epoch 557/1000
# 1/1 [==============================] - 1s 747ms/step - loss: 0.0833
# Epoch 558/1000
# 1/1 [==============================] - 1s 755ms/step - loss: 0.0833
# Epoch 559/1000
# 1/1 [==============================] - 1s 792ms/step - loss: 0.0833
# Epoch 560/1000
# 1/1 [==============================] - 1s 752ms/step - loss: 0.0833
# Epoch 561/1000
# 1/1 [==============================] - 0s 444ms/step - loss: 0.0833
# Epoch 562/1000
# 1/1 [==============================] - 0s 417ms/step - loss: 0.0833
# Epoch 563/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0833
# Epoch 564/1000
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0833
# Epoch 565/1000
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0833
# Epoch 566/1000
# 1/1 [==============================] - 0s 427ms/step - loss: 0.0833
# Epoch 567/1000
# 1/1 [==============================] - 0s 418ms/step - loss: 0.0833
# Epoch 568/1000
# 1/1 [==============================] - 0s 429ms/step - loss: 0.0833
# Epoch 569/1000
# 1/1 [==============================] - 0s 425ms/step - loss: 0.0833
# Epoch 570/1000
# 1/1 [==============================] - 0s 440ms/step - loss: 0.0833
# Epoch 571/1000
# 1/1 [==============================] - 0s 458ms/step - loss: 0.0833
# Epoch 572/1000
# 1/1 [==============================] - 0s 435ms/step - loss: 0.0833
# Epoch 573/1000
# 1/1 [==============================] - 0s 423ms/step - loss: 0.0833
# Epoch 574/1000
# 1/1 [==============================] - 0s 458ms/step - loss: 0.0833
# Epoch 575/1000
# 1/1 [==============================] - 0s 437ms/step - loss: 0.0833
# Epoch 576/1000
# 1/1 [==============================] - 0s 431ms/step - loss: 0.0833
# Epoch 577/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0833
# Epoch 578/1000
# 1/1 [==============================] - 0s 430ms/step - loss: 0.0833
# Epoch 579/1000
# 1/1 [==============================] - 0s 424ms/step - loss: 0.0833
# Epoch 580/1000
# 1/1 [==============================] - 0s 426ms/step - loss: 0.0833
# Epoch 581/1000
# ...
# 1/1 [==============================] - 0s 463ms/step - loss: 0.0833
# Epoch 809/1000
# 1/1 [==============================] - 0s 478ms/step - loss: 0.0833
# Epoch 810/1000
# 1/1 [==============================] - 0s 470ms/step - loss: 0.0833
# Epoch 811/1000
# 1/1 [==============================] - 0s 462ms/step - loss: 0.0833
# Epoch 812/1000
# 1/1 [==============================] - 0s 421ms/step - loss: 0.0833
# Epoch 813/1000
# 1/1 [==============================] - 0s 462ms/step - loss: 0.0833
# Epoch 814/1000
# 1/1 [==============================] - 0s 431ms/step - loss: 0.0833
# Epoch 815/1000
# 1/1 [==============================] - 0s 428ms/step - loss: 0.0833
# Epoch 816/1000
# 1/1 [==============================] - 0s 465ms/step - loss: 0.0833
# Epoch 817/1000
# 1/1 [==============================] - 0s 457ms/step - loss: 0.0833
# Epoch 818/1000
# 1/1 [==============================] - 0s 480ms/step - loss: 0.0833
# Epoch 819/1000
# 1/1 [==============================] - 0s 428ms/step - loss: 0.0833
# Epoch 820/1000
# 1/1 [==============================] - 1s 525ms/step - loss: 0.0833
# Epoch 821/1000
# 1/1 [==============================] - 1s 695ms/step - loss: 0.0833
# Epoch 822/1000
# 1/1 [==============================] - 1s 843ms/step - loss: 0.0833
# Epoch 823/1000
# 1/1 [==============================] - 1s 747ms/step - loss: 0.0833
# Epoch 824/1000
# 1/1 [==============================] - 1s 728ms/step - loss: 0.0833
# Epoch 825/1000
# 1/1 [==============================] - 1s 780ms/step - loss: 0.0833
# Epoch 826/1000
# 1/1 [==============================] - 1s 691ms/step - loss: 0.0833
# Epoch 827/1000
# 1/1 [==============================] - 0s 429ms/step - loss: 0.0833
# Epoch 828/1000
# 1/1 [==============================] - 0s 476ms/step - loss: 0.0833
# Epoch 829/1000
# 1/1 [==============================] - 0s 464ms/step - loss: 0.0833
# Epoch 830/1000
# 1/1 [==============================] - 0s 470ms/step - loss: 0.0833
# Epoch 831/1000
# 1/1 [==============================] - 0s 420ms/step - loss: 0.0833
# Epoch 832/1000
# 1/1 [==============================] - 0s 429ms/step - loss: 0.0833
# Epoch 833/1000
# 1/1 [==============================] - 0s 443ms/step - loss: 0.0833
# Epoch 834/1000
# 1/1 [==============================] - 0s 425ms/step - loss: 0.0833
# Epoch 835/1000
# 1/1 [==============================] - 0s 446ms/step - loss: 0.0833
# Epoch 836/1000
# 1/1 [==============================] - 0s 423ms/step - loss: 0.0833
# Epoch 837/1000
# 1/1 [==============================] - 0s 464ms/step - loss: 0.0833
# Epoch 838/1000
# 1/1 [==============================] - 0s 451ms/step - loss: 0.0833
# Epoch 839/1000
# 1/1 [==============================] - 0s 424ms/step - loss: 0.0833
# Epoch 840/1000
# 1/1 [==============================] - 0s 478ms/step - loss: 0.0833
# Epoch 841/1000
# 1/1 [==============================] - 0s 468ms/step - loss: 0.0833
# Epoch 842/1000
# 1/1 [==============================] - 0s 441ms/step - loss: 0.0833
# Epoch 843/1000
# 1/1 [==============================] - 0s 459ms/step - loss: 0.0833
# Epoch 844/1000
# 1/1 [==============================] - 1s 801ms/step - loss: 0.0833
# Epoch 845/1000
# 1/1 [==============================] - 1s 733ms/step - loss: 0.0833
# Epoch 846/1000
# 1/1 [==============================] - 1s 888ms/step - loss: 0.0833
# Epoch 847/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.0833
# Epoch 848/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.0833
# Epoch 849/1000
# 1/1 [==============================] - 1s 844ms/step - loss: 0.0833
# Epoch 850/1000
# 1/1 [==============================] - 1s 826ms/step - loss: 0.0833
# Epoch 851/1000
# 1/1 [==============================] - 1s 652ms/step - loss: 0.0833
# Epoch 852/1000
# 1/1 [==============================] - 0s 475ms/step - loss: 0.0833
# Epoch 853/1000
# 1/1 [==============================] - 1s 668ms/step - loss: 0.0833
# Epoch 854/1000
# 1/1 [==============================] - 1s 545ms/step - loss: 0.0833
# Epoch 855/1000
# 1/1 [==============================] - 0s 467ms/step - loss: 0.0833
# Epoch 856/1000
# 1/1 [==============================] - 0s 442ms/step - loss: 0.0833
# Epoch 857/1000
# 1/1 [==============================] - 1s 590ms/step - loss: 0.0833
# Epoch 858/1000
# 1/1 [==============================] - 1s 877ms/step - loss: 0.0833
# Epoch 859/1000
# 1/1 [==============================] - 1s 569ms/step - loss: 0.0833
# Epoch 860/1000
# 1/1 [==============================] - 0s 441ms/step - loss: 0.0833
# Epoch 861/1000
# 1/1 [==============================] - 0s 451ms/step - loss: 0.0833
# Epoch 862/1000
# 1/1 [==============================] - 0s 437ms/step - loss: 0.0833
# Epoch 863/1000
# 1/1 [==============================] - 0s 463ms/step - loss: 0.0833
# Epoch 864/1000
# 1/1 [==============================] - 0s 473ms/step - loss: 0.0833
# Epoch 865/1000
# 1/1 [==============================] - 1s 607ms/step - loss: 0.0833
# Epoch 866/1000
# 1/1 [==============================] - 1s 875ms/step - loss: 0.0833
# Epoch 867/1000
# 1/1 [==============================] - 1s 902ms/step - loss: 0.0833
# Epoch 868/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.0833
# Epoch 869/1000
# 1/1 [==============================] - 1s 791ms/step - loss: 0.0833
# Epoch 870/1000
# 1/1 [==============================] - 1s 750ms/step - loss: 0.0833
# Epoch 871/1000
# 1/1 [==============================] - 1s 719ms/step - loss: 0.0833
# Epoch 872/1000
# 1/1 [==============================] - 1s 799ms/step - loss: 0.0833
# Epoch 873/1000
# 1/1 [==============================] - 1s 793ms/step - loss: 0.0833
# Epoch 874/1000
# 1/1 [==============================] - 1s 890ms/step - loss: 0.0833
# Epoch 875/1000
# 1/1 [==============================] - 1s 762ms/step - loss: 0.0833
# Epoch 876/1000
# 1/1 [==============================] - 1s 763ms/step - loss: 0.0833
# Epoch 877/1000
# 1/1 [==============================] - 1s 873ms/step - loss: 0.0833
# Epoch 878/1000
# 1/1 [==============================] - 1s 821ms/step - loss: 0.0833
# Epoch 879/1000
# 1/1 [==============================] - 1s 692ms/step - loss: 0.0833
# Epoch 880/1000
# 1/1 [==============================] - 0s 484ms/step - loss: 0.0833
# Epoch 881/1000
# 1/1 [==============================] - 0s 463ms/step - loss: 0.0833
# Epoch 882/1000
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0833
# Epoch 883/1000
# 1/1 [==============================] - 1s 836ms/step - loss: 0.0833
# Epoch 884/1000
# 1/1 [==============================] - 1s 692ms/step - loss: 0.0833
# Epoch 885/1000
# 1/1 [==============================] - 0s 445ms/step - loss: 0.0833
# Epoch 886/1000
# 1/1 [==============================] - 0s 457ms/step - loss: 0.0833
# Epoch 887/1000
# 1/1 [==============================] - 0s 448ms/step - loss: 0.0833
# Epoch 888/1000
# 1/1 [==============================] - 0s 440ms/step - loss: 0.0833
# Epoch 889/1000
# 1/1 [==============================] - 0s 468ms/step - loss: 0.0833
# Epoch 890/1000
# 1/1 [==============================] - 0s 435ms/step - loss: 0.0833
# Epoch 891/1000
# 1/1 [==============================] - 0s 440ms/step - loss: 0.0833
# Epoch 892/1000
# 1/1 [==============================] - 1s 717ms/step - loss: 0.0833
# Epoch 893/1000
# 1/1 [==============================] - 1s 834ms/step - loss: 0.0833
# Epoch 894/1000
# 1/1 [==============================] - 1s 746ms/step - loss: 0.0833
# Epoch 895/1000
# 1/1 [==============================] - 1s 811ms/step - loss: 0.0833
# Epoch 896/1000
# 1/1 [==============================] - 1s 769ms/step - loss: 0.0833
# Epoch 897/1000
# 1/1 [==============================] - 1s 726ms/step - loss: 0.0833
# Epoch 898/1000
# 1/1 [==============================] - 0s 474ms/step - loss: 0.0833
# Epoch 899/1000
# 1/1 [==============================] - 0s 473ms/step - loss: 0.0833
# Epoch 900/1000
# 1/1 [==============================] - 0s 464ms/step - loss: 0.0833
# Epoch 901/1000
# 1/1 [==============================] - 0s 450ms/step - loss: 0.0833
# Epoch 902/1000
# 1/1 [==============================] - 0s 442ms/step - loss: 0.0833
# Epoch 903/1000
# 1/1 [==============================] - 0s 448ms/step - loss: 0.0833
# Epoch 904/1000
# 1/1 [==============================] - 0s 421ms/step - loss: 0.0833
# Epoch 905/1000
# 1/1 [==============================] - 0s 435ms/step - loss: 0.0833
# Epoch 906/1000
# 1/1 [==============================] - 0s 436ms/step - loss: 0.0833
# Epoch 907/1000
# 1/1 [==============================] - 0s 422ms/step - loss: 0.0833
# Epoch 908/1000
# 1/1 [==============================] - 0s 445ms/step - loss: 0.0833
# Epoch 909/1000
# 1/1 [==============================] - 0s 451ms/step - loss: 0.0833
# Epoch 910/1000
# 1/1 [==============================] - 0s 470ms/step - loss: 0.0833
# Epoch 911/1000
# 1/1 [==============================] - 0s 425ms/step - loss: 0.0833
# Epoch 912/1000
# 1/1 [==============================] - 0s 459ms/step - loss: 0.0833
# Epoch 913/1000
# 1/1 [==============================] - 0s 466ms/step - loss: 0.0833
# Epoch 914/1000
# 1/1 [==============================] - 0s 429ms/step - loss: 0.0833
# Epoch 915/1000
# 1/1 [==============================] - 0s 447ms/step - loss: 0.0833
# Epoch 916/1000
# 1/1 [==============================] - 0s 453ms/step - loss: 0.0833
# Epoch 917/1000
# 1/1 [==============================] - 0s 467ms/step - loss: 0.0833
# Epoch 918/1000
# 1/1 [==============================] - 0s 459ms/step - loss: 0.0833
# Epoch 919/1000
# 1/1 [==============================] - 0s 463ms/step - loss: 0.0833
# Epoch 920/1000
# 1/1 [==============================] - 1s 690ms/step - loss: 0.0833
# Epoch 921/1000
# 1/1 [==============================] - 1s 862ms/step - loss: 0.0833
# Epoch 922/1000
# 1/1 [==============================] - 1s 747ms/step - loss: 0.0833
# Epoch 923/1000
# 1/1 [==============================] - 1s 842ms/step - loss: 0.0833
# Epoch 924/1000
# 1/1 [==============================] - 1s 834ms/step - loss: 0.0833
# Epoch 925/1000
# 1/1 [==============================] - 1s 731ms/step - loss: 0.0833
# Epoch 926/1000
# 1/1 [==============================] - 0s 437ms/step - loss: 0.0833
# Epoch 927/1000
# 1/1 [==============================] - 0s 441ms/step - loss: 0.0833
# Epoch 928/1000
# 1/1 [==============================] - 0s 447ms/step - loss: 0.0833
# Epoch 929/1000
# 1/1 [==============================] - 0s 429ms/step - loss: 0.0833
# Epoch 930/1000
# 1/1 [==============================] - 0s 427ms/step - loss: 0.0833
# Epoch 931/1000
# 1/1 [==============================] - 0s 433ms/step - loss: 0.0833
# Epoch 932/1000
# 1/1 [==============================] - 0s 441ms/step - loss: 0.0833
# Epoch 933/1000
# 1/1 [==============================] - 0s 444ms/step - loss: 0.0833
# Epoch 934/1000
# 1/1 [==============================] - 0s 463ms/step - loss: 0.0833
# Epoch 935/1000
# 1/1 [==============================] - 0s 444ms/step - loss: 0.0833
# Epoch 936/1000
# 1/1 [==============================] - 0s 456ms/step - loss: 0.0833
# Epoch 937/1000
# 1/1 [==============================] - 0s 464ms/step - loss: 0.0833
# Epoch 938/1000
# 1/1 [==============================] - 0s 457ms/step - loss: 0.0833
# Epoch 939/1000
# 1/1 [==============================] - 0s 462ms/step - loss: 0.0833
# Epoch 940/1000
# 1/1 [==============================] - 0s 457ms/step - loss: 0.0833
# Epoch 941/1000
# 1/1 [==============================] - 0s 484ms/step - loss: 0.0833
# Epoch 942/1000
# 1/1 [==============================] - 0s 465ms/step - loss: 0.0833
# Epoch 943/1000
# 1/1 [==============================] - 0s 437ms/step - loss: 0.0833
# Epoch 944/1000
# 1/1 [==============================] - 0s 453ms/step - loss: 0.0833
# Epoch 945/1000
# 1/1 [==============================] - 0s 436ms/step - loss: 0.0833
# Epoch 946/1000
# 1/1 [==============================] - 0s 446ms/step - loss: 0.0833
# Epoch 947/1000
# 1/1 [==============================] - 0s 437ms/step - loss: 0.0833
# Epoch 948/1000
# 1/1 [==============================] - 1s 725ms/step - loss: 0.0833
# Epoch 949/1000
# 1/1 [==============================] - 1s 827ms/step - loss: 0.0833
# Epoch 950/1000
# 1/1 [==============================] - 1s 715ms/step - loss: 0.0833
# Epoch 951/1000
# 1/1 [==============================] - 1s 800ms/step - loss: 0.0833
# Epoch 952/1000
# 1/1 [==============================] - 1s 744ms/step - loss: 0.0833
# Epoch 953/1000
# 1/1 [==============================] - 1s 725ms/step - loss: 0.0833
# Epoch 954/1000
# 1/1 [==============================] - 1s 568ms/step - loss: 0.0833
# Epoch 955/1000
# 1/1 [==============================] - 0s 435ms/step - loss: 0.0833
# Epoch 956/1000
# 1/1 [==============================] - 0s 439ms/step - loss: 0.0833
# Epoch 957/1000
# 1/1 [==============================] - 0s 464ms/step - loss: 0.0833
# Epoch 958/1000
# 1/1 [==============================] - 0s 477ms/step - loss: 0.0833
# Epoch 959/1000
# 1/1 [==============================] - 0s 455ms/step - loss: 0.0833
# Epoch 960/1000
# 1/1 [==============================] - 0s 433ms/step - loss: 0.0833
# Epoch 961/1000
# 1/1 [==============================] - 1s 571ms/step - loss: 0.0833
# Epoch 962/1000
# 1/1 [==============================] - 1s 831ms/step - loss: 0.0833
# Epoch 963/1000
# 1/1 [==============================] - 1s 733ms/step - loss: 0.0833
# Epoch 964/1000
# 1/1 [==============================] - 1s 750ms/step - loss: 0.0833
# Epoch 965/1000
# 1/1 [==============================] - 1s 745ms/step - loss: 0.0833
# Epoch 966/1000
# 1/1 [==============================] - 1s 920ms/step - loss: 0.0833
# Epoch 967/1000
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0833
# Epoch 968/1000
# 1/1 [==============================] - 1s 733ms/step - loss: 0.0833
# Epoch 969/1000
# 1/1 [==============================] - 1s 834ms/step - loss: 0.0833
# Epoch 970/1000
# 1/1 [==============================] - 1s 978ms/step - loss: 0.0833
# Epoch 971/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.0833
# Epoch 972/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.0833
# Epoch 973/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0833
# Epoch 974/1000
# 1/1 [==============================] - 0s 447ms/step - loss: 0.0833
# Epoch 975/1000
# 1/1 [==============================] - 0s 470ms/step - loss: 0.0833
# Epoch 976/1000
# 1/1 [==============================] - 0s 456ms/step - loss: 0.0833
# Epoch 977/1000
# 1/1 [==============================] - 0s 468ms/step - loss: 0.0833
# Epoch 978/1000
# 1/1 [==============================] - 0s 435ms/step - loss: 0.0833
# Epoch 979/1000
# 1/1 [==============================] - 0s 455ms/step - loss: 0.0833
# Epoch 980/1000
# 1/1 [==============================] - 0s 482ms/step - loss: 0.0833
# Epoch 981/1000
# 1/1 [==============================] - 0s 449ms/step - loss: 0.0833
# Epoch 982/1000
# 1/1 [==============================] - 0s 460ms/step - loss: 0.0833
# Epoch 983/1000
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0833
# Epoch 984/1000
# 1/1 [==============================] - 0s 430ms/step - loss: 0.0833
# Epoch 985/1000
# 1/1 [==============================] - 0s 426ms/step - loss: 0.0833
# Epoch 986/1000
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0833
# Epoch 987/1000
# 1/1 [==============================] - 0s 471ms/step - loss: 0.0833
# Epoch 988/1000
# 1/1 [==============================] - 0s 423ms/step - loss: 0.0833
# Epoch 989/1000
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0833
# Epoch 990/1000
# 1/1 [==============================] - 0s 455ms/step - loss: 0.0833
# Epoch 991/1000
# 1/1 [==============================] - 0s 438ms/step - loss: 0.0833
# Epoch 992/1000
# 1/1 [==============================] - 0s 467ms/step - loss: 0.0833
# Epoch 993/1000
# 1/1 [==============================] - 0s 468ms/step - loss: 0.0833
# Epoch 994/1000
# 1/1 [==============================] - 0s 453ms/step - loss: 0.0833
# Epoch 995/1000
# 1/1 [==============================] - 1s 521ms/step - loss: 0.0833
# Epoch 996/1000
# 1/1 [==============================] - 1s 717ms/step - loss: 0.0833
# Epoch 997/1000
# 1/1 [==============================] - 1s 772ms/step - loss: 0.0833
# Epoch 998/1000
# 1/1 [==============================] - 1s 793ms/step - loss: 0.0833
# Epoch 999/1000
# 1/1 [==============================] - 1s 797ms/step - loss: 0.0833
# Epoch 1000/1000
# 1/1 [==============================] - 1s 715ms/step - loss: 0.0833

# %%
# Plot the loss function per epoch
plt.plot(history.history['loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.show()

# %%
input_data.shape
# Out:
# (1, 257, 257, 3)

# %%
# Generate predictions using the trained model
predictions = model.predict(input_data)

# Reshape and transpose arrays if needed
u_initial = np.squeeze(u_initial)
v_initial = np.squeeze(v_initial)
p_initial = np.squeeze(p_initial)
predictions = np.squeeze(predictions)

print("u_initial shape:", u_initial.shape)
print("v_initial shape:", v_initial.shape)
print("p_initial shape:", p_initial.shape)
print("predictions shape:", predictions.shape)
# Out:
# 1/1 [==============================] - 0s 149ms/step
# u_initial shape: (257, 257)
# v_initial shape: (257, 257)
# p_initial shape: (257, 257)
# predictions shape: (3,)

# %%
predictions.shape
# Out:
# (3,)

# %%
predictions = predictions.reshape(u_initial.shape)
print("predictions shape:", predictions.shape)
# Plot a comparison between the model predictions and the original data
fig, axes = plt.subplots(2, 3, figsize=(10, 6))
titles = ['u Initial', 'v Initial', 'p Initial', 'u Prediction', 'v Prediction', 'p Prediction']
data = [u_initial, v_initial, p_initial, predictions[..., 0], predictions[..., 1], predictions[..., 2]]
for i, ax in enumerate(axes.flat):
    im = ax.imshow(data[i], cmap='jet', origin='lower')
    ax.set_title(titles[i])
    fig.colorbar(im, ax=ax)
plt.tight_layout()
plt.show()

# %%
# Generate predictions using the trained model
predictions = model.predict(input_data)

# Create mesh for X and Y inputs to the figure
x = np.linspace(0, length, colpts)
y = np.linspace(0, breadth, rowpts)
[X, Y] = np.meshgrid(x, y)

# Determine indexing for stream plot (10 points only)
index_cut_x = int(colpts / 10)
index_cut_y = int(rowpts / 10)

# Create blank figure
fig, axes = plt.subplots(2, 3, figsize=(10, 6))
titles = ['u Initial', 'v Initial', 'p Initial', 'u Prediction', 'v Prediction', 'p Prediction']
data = [u_initial, v_initial, p_initial, predictions[..., 0], predictions[..., 1], predictions[..., 2]]

for i, ax in enumerate(axes.flat):
    # Clear previous plot and make contour and stream plots for each data
    ax.clear()
    ax.set_xlim([0, length])
    ax.set_ylim([0, breadth])
    ax.set_xlabel("$x$", fontsize=12)
    ax.set_ylabel("$y$", fontsize=12)
    ax.set_title(titles[i])

    if i < 3:
        # Original data
        cont = ax.contourf(X, Y, data[i], cmap='jet', origin='lower')
    else:
        # Predictions
        cont = ax.contourf(X, Y, data[i], cmap='jet', origin='lower')

    if i == 2:
        fig.colorbar(cont, ax=ax)

    if i >= 3:
        # Stream plots for u and v predictions
        stream = ax.streamplot(X[::index_cut_y, ::index_cut_x], Y[::index_cut_y, ::index_cut_x],
                               data[i-3][::index_cut_y, ::index_cut_x], data[i-2][::index_cut_y, ::index_cut_x],
                               color="k")

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 89ms/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-b1a4f56cbfad> in <cell line: 18>()
#      30     else:
#      31         # Predictions
# ---> 32         cont = ax.contourf(X, Y, data[i], cmap='jet', origin='lower')
#      33
#      34     if i == 2:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    6465         """
#    6466         kwargs['filled'] = True
# -> 6467         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6468         self._request_autoscale_view()
#    6469         return contours
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, *args, **kwargs)
#     767                 mpl.rcParams['contour.negative_linestyle']
#     768
# --> 769         kwargs = self._process_args(*args, **kwargs)
#     770         self._process_levels()
#     771
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/contour.py in _process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1409             self._corner_mask = corner_mask
#    1410
# -> 1411             x, y, z = self._contour_args(args, kwargs)
#    1412
#    1413             contour_generator = contourpy.contour_generator(
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1448         elif nargs <= 4:
#    1449             x, y, z_orig, *args = args
# -> 1450             x, y, z = self._check_xyz(x, y, z_orig, kwargs)
#    1451         else:
#    1452             raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/contour.py in _check_xyz(self, x, y, z, kwargs)
#    1473
#    1474         if z.ndim != 2:
# -> 1475             raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1476         if z.shape[0] < 2 or z.shape[1] < 2:
#    1477             raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#
# TypeError: Input z must be 2D, not 1D

# %%
# Define the PINN architecture
model = tf.keras.Sequential([
    tf.keras.layers.Dense(256, activation='relu', input_shape=(257, 257, 3)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(257, activation='linear')
])

# %%
# Define the custom loss function incorporating the physics equations
def custom_loss(y_true, y_pred):
    # Extract the predicted u, v, and p
    u_pred = y_pred[:, :, 0]
    v_pred = y_pred[:, :, 1]
    p_pred = y_pred[:, :, 2]

    # Compute the gradients of u and v
    u_grads = tf.gradients(u_pred, x)[0]
    v_grads = tf.gradients(v_pred, y)[0]

    # Compute the divergence of the velocity field
    div_vel = tf.gradients(u_pred, x)[0] + tf.gradients(v_pred, y)[0]

    # Compute the loss terms based on the physics equations
    loss_eq1 = tf.reduce_mean(tf.square(u_grads + p_pred))
    loss_eq2 = tf.reduce_mean(tf.square(v_grads + p_pred))
    loss_eq3 = tf.reduce_mean(tf.square(div_vel))

    # Combine the loss terms
    total_loss = loss_eq1 + loss_eq2 + loss_eq3

    return total_loss

# Compile the model with the custom loss function
model.compile(optimizer=tf.keras.optimizers.Adam(), loss=custom_loss)

# %%
# Train the model
history = model.fit(input_data, target_data, epochs=1000, batch_size=1)
# Out:
# Epoch 1/1000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-389210f3143d> in <cell line: 2>()
#       1 # Train the model
# ----> 2 history = model.fit(input_data, target_data, epochs=1000, batch_size=1)
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# /tmp/__autograph_generated_fileg5i6w0e7.py in tf__custom_loss(y_true, y_pred)
#      13                 u_grads = ag__.converted_call(ag__.ld(tf).gradients, (ag__.ld(u_pred), ag__.ld(x)), None, fscope)[0]
#      14                 v_grads = ag__.converted_call(ag__.ld(tf).gradients, (ag__.ld(v_pred), ag__.ld(y)), None, fscope)[0]
# ---> 15                 div_vel = ag__.converted_call(ag__.ld(tf).gradients, (ag__.ld(u_pred), ag__.ld(x)), None, fscope)[0] + ag__.converted_call(ag__.ld(tf).gradients, (ag__.ld(v_pred), ag__.ld(y)), None, fscope)[0]
#      16                 loss_eq1 = ag__.converted_call(ag__.ld(tf).reduce_mean, (ag__.converted_call(ag__.ld(tf).square, (ag__.ld(u_grads) + ag__.ld(p_pred),), None, fscope),), None, fscope)
#      17                 loss_eq2 = ag__.converted_call(ag__.ld(tf).reduce_mean, (ag__.converted_call(ag__.ld(tf).square, (ag__.ld(v_grads) + ag__.ld(p_pred),), None, fscope),), None, fscope)
#
# TypeError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1284, in train_function  *
#         return step_function(self, iterator)
#     File "<ipython-input-103-dc766d59ea04>", line 13, in custom_loss  *
#         div_vel = tf.gradients(u_pred, x)[0] + tf.gradients(v_pred, y)[0]
#
#     TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'

# %%
# Plot the loss function per epoch
plt.plot(history.history['loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.show()

# %%
# Generate predictions using the trained model
predictions = model.predict(input_data)

# Plot a comparison between the model predictions and the original data
fig, axes = plt.subplots(2, 3, figsize=(10, 6))
titles = ['u Initial', 'v Initial', 'p Initial', 'u Prediction', 'v Prediction', 'p Prediction']
data = [u_initial, v_initial, p_initial, predictions[..., 0], predictions[..., 1], predictions[..., 2]]
for i, ax in enumerate(axes.flat):
    im = ax.imshow(data[i], cmap='jet', origin='lower')
    ax.set_title(titles[i])
    fig.colorbar(im, ax=ax)
plt.tight_layout()
plt.show()
